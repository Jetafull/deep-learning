# %% [markdown]
# # Anna KaRNNa
#
# In this notebook, I'll build a character-wise RNN trained on Anna Karenina, one of my all-time favorite books. It'll be able to generate new text based on the text from the book.
#
# This network is based off of Andrej Karpathy's [post on RNNs](http://karpathy.github.io/2015/05/21/rnn-effectiveness/) and [implementation in Torch](https://github.com/karpathy/char-rnn). Also, some information [here at r2rt](http://r2rt.com/recurrent-neural-networks-in-tensorflow-ii.html) and from [Sherjil Ozair](https://github.com/sherjilozair/char-rnn-tensorflow) on GitHub. Below is the general architecture of the character-wise RNN.
#
# <img src="assets/charseq.jpeg" width="500">

# %%
import time
from collections import namedtuple

import numpy as np
import tensorflow as tf

# %% [markdown]
# First we'll load the text file and convert it into integers for our network to use.

# %%
with open('anna.txt', 'r') as f:
    text=f.read()
vocab = set(text)
vocab_to_int = {c: i for i, c in enumerate(vocab)}
int_to_vocab = dict(enumerate(vocab))
chars = np.array([vocab_to_int[c] for c in text], dtype=np.int32)

# %%
text[:100]
# Out:
# 'Chapter 1\n\n\nHappy families are all alike; every unhappy family is unhappy in its own\nway.\n\nEverythin'

# %%
chars[:100]
# Out:
# array([ 5, 81,  0, 61, 32, 70, 30, 76, 12, 11, 11, 11, 78,  0, 61, 61, 37,
#        76, 28,  0, 80,  3, 71,  3, 70, 13, 76,  0, 30, 70, 76,  0, 71, 71,
#        76,  0, 71,  3, 55, 70, 14, 76, 70, 15, 70, 30, 37, 76, 43, 23, 81,
#         0, 61, 61, 37, 76, 28,  0, 80,  3, 71, 37, 76,  3, 13, 76, 43, 23,
#        81,  0, 61, 61, 37, 76,  3, 23, 76,  3, 32, 13, 76, 35, 65, 23, 11,
#        65,  0, 37, 56, 11, 11, 48, 15, 70, 30, 37, 32, 81,  3, 23], dtype=int32)

# %% [markdown]
# Now I need to split up the data into batches, and into training and validation sets. I should be making a test set here, but I'm not going to worry about that. My test will be if the network can generate new text.
#
# Here I'll make both input and target arrays. The targets are the same as the inputs, except shifted one character over. I'll also drop the last bit of data so that I'll only have completely full batches.
#
# The idea here is to make a 2D matrix where the number of rows is equal to the number of batches. Each row will be one long concatenated string from the character data. We'll split this data into a training set and validation set using the `split_frac` keyword. This will keep 90% of the batches in the training set, the other 10% in the validation set.

# %%
def split_data(chars, batch_size, num_steps, split_frac=0.9):
    """ 
    Split character data into training and validation sets, inputs and targets for each set.
    
    Arguments
    ---------
    chars: character array
    batch_size: Size of examples in each of batch
    num_steps: Number of sequence steps to keep in the input and pass to the network
    split_frac: Fraction of batches to keep in the training set
    
    
    Returns train_x, train_y, val_x, val_y
    """
    
    
    slice_size = batch_size * num_steps
    n_batches = int(len(chars) / slice_size)
    
    # Drop the last few characters to make only full batches
    x = chars[: n_batches*slice_size]
    y = chars[1: n_batches*slice_size + 1]
    
    # Split the data into batch_size slices, then stack them into a 2D matrix 
    x = np.stack(np.split(x, batch_size))
    y = np.stack(np.split(y, batch_size))
    
    # Now x and y are arrays with dimensions batch_size x n_batches*num_steps
    
    # Split into training and validation sets, keep the virst split_frac batches for training
    split_idx = int(n_batches*split_frac)
    train_x, train_y= x[:, :split_idx*num_steps], y[:, :split_idx*num_steps]
    val_x, val_y = x[:, split_idx*num_steps:], y[:, split_idx*num_steps:]
    
    return train_x, train_y, val_x, val_y

# %%
train_x, train_y, val_x, val_y = split_data(chars, 10, 200)

# %%
train_x.shape
# Out:
# (10, 178400)

# %%
train_x[:,:10]
# Out:
# array([[ 5, 81,  0, 61, 32, 70, 30, 76, 12, 11],
#        [73, 23, 41, 76, 81, 70, 76, 80, 35, 15],
#        [76, 64,  0, 32, 64, 81,  3, 23, 42, 76],
#        [35, 32, 81, 70, 30, 76, 65, 35, 43, 71],
#        [76, 32, 81, 70, 76, 71,  0, 23, 41, 59],
#        [76, 60, 81, 30, 35, 43, 42, 81, 76, 71],
#        [32, 76, 32, 35, 11, 41, 35, 56, 11, 11],
#        [35, 76, 81, 70, 30, 13, 70, 71, 28, 57],
#        [81,  0, 32, 76,  3, 13, 76, 32, 81, 70],
#        [70, 30, 13, 70, 71, 28, 76,  0, 23, 41]], dtype=int32)

# %% [markdown]
# I'll write another function to grab batches out of the arrays made by split data. Here each batch will be a sliding window on these arrays with size `batch_size X num_steps`. For example, if we want our network to train on a sequence of 100 characters, `num_steps = 100`. For the next batch, we'll shift this window the next sequence of `num_steps` characters. In this way we can feed batches to the network and the cell states will continue through on each batch.

# %%
def get_batch(arrs, num_steps):
    batch_size, slice_size = arrs[0].shape
    
    n_batches = int(slice_size/num_steps)
    for b in range(n_batches):
        yield [x[:, b*num_steps: (b+1)*num_steps] for x in arrs]

# %%
def build_rnn(num_classes, batch_size=50, num_steps=50, lstm_size=128, num_layers=2,
              learning_rate=0.001, grad_clip=5, sampling=False):
        
    if sampling == True:
        batch_size, num_steps = 1, 1

    tf.reset_default_graph()
    
    # Declare placeholders we'll feed into the graph
    with tf.name_scope('inputs'):
        inputs = tf.placeholder(tf.int32, [batch_size, num_steps], name='inputs')
        x_one_hot = tf.one_hot(inputs, num_classes, name='x_one_hot')
    
    with tf.name_scope('targets'):
        targets = tf.placeholder(tf.int32, [batch_size, num_steps], name='targets')
        y_one_hot = tf.one_hot(targets, num_classes, name='y_one_hot')
        y_reshaped = tf.reshape(y_one_hot, [-1, num_classes])
    
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    
    # Build the RNN layers
    with tf.name_scope("RNN_layers"):
        def create_cell(lstm_size, keep_prob):   
            lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
            drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
            return drop
        cell = tf.contrib.rnn.MultiRNNCell([create_cell(lstm_size, keep_prob) for _ in range(num_layers)])
    
    with tf.name_scope("RNN_init_state"):
        initial_state = cell.zero_state(batch_size, tf.float32)

    # Run the data through the RNN layers
    with tf.name_scope("RNN_forward"):
        outputs, state = tf.nn.dynamic_rnn(cell, x_one_hot, initial_state=initial_state)
    
    final_state = state
    
    # Reshape output so it's a bunch of rows, one row for each cell output
    with tf.name_scope('sequence_reshape'):
        seq_output = tf.concat(outputs, axis=1,name='seq_output')
        output = tf.reshape(seq_output, [-1, lstm_size], name='graph_output')
    
    # Now connect the RNN putputs to a softmax layer and calculate the cost
    with tf.name_scope('logits'):
        softmax_w = tf.Variable(tf.truncated_normal((lstm_size, num_classes), stddev=0.1),
                               name='softmax_w')
        softmax_b = tf.Variable(tf.zeros(num_classes), name='softmax_b')
        logits = tf.matmul(output, softmax_w) + softmax_b

    with tf.name_scope('predictions'):
        preds = tf.nn.softmax(logits, name='predictions')
    
    
    with tf.name_scope('cost'):
        loss = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y_reshaped, name='loss')
        cost = tf.reduce_mean(loss, name='cost')

    # Optimizer for training, using gradient clipping to control exploding gradients
    with tf.name_scope('train'):
        tvars = tf.trainable_variables()
        grads, _ = tf.clip_by_global_norm(tf.gradients(cost, tvars), grad_clip)
        train_op = tf.train.AdamOptimizer(learning_rate)
        optimizer = train_op.apply_gradients(zip(grads, tvars))
    
    # Export the nodes 
    export_nodes = ['inputs', 'targets', 'initial_state', 'final_state',
                    'keep_prob', 'cost', 'preds', 'optimizer']
    Graph = namedtuple('Graph', export_nodes)
    local_dict = locals()
    graph = Graph(*[local_dict[each] for each in export_nodes])
    
    return graph

# %% [markdown]
# ## Hyperparameters
#
# Here I'm defining the hyperparameters for the network. The two you probably haven't seen before are `lstm_size` and `num_layers`. These set the number of hidden units in the LSTM layers and the number of LSTM layers, respectively. Of course, making these bigger will improve the network's performance but you'll have to watch out for overfitting. If your validation loss is much larger than the training loss, you're probably overfitting. Decrease the size of the network or decrease the dropout keep probability.

# %%
batch_size = 100
num_steps = 100
lstm_size = 512
num_layers = 2
learning_rate = 0.001

# %% [markdown]
# ## Write out the graph for TensorBoard

# %%
model = build_rnn(len(vocab), 
                  batch_size=batch_size,
                  num_steps=num_steps,
                  learning_rate=learning_rate,
                  lstm_size=lstm_size,
                  num_layers=num_layers)

with tf.Session() as sess:
    
    sess.run(tf.global_variables_initializer())
    file_writer = tf.summary.FileWriter('./logs/3', sess.graph)

# %% [markdown]
# ## Training
#
# Time for training which is is pretty straightforward. Here I pass in some data, and get an LSTM state back. Then I pass that state back in to the network so the next batch can continue the state from the previous batch. And every so often (set by `save_every_n`) I calculate the validation loss and save a checkpoint.

# %%
# !mkdir -p checkpoints/anna

# %%
epochs = 10
save_every_n = 200
train_x, train_y, val_x, val_y = split_data(chars, batch_size, num_steps)

model = build_rnn(len(vocab), 
                  batch_size=batch_size,
                  num_steps=num_steps,
                  learning_rate=learning_rate,
                  lstm_size=lstm_size,
                  num_layers=num_layers)

saver = tf.train.Saver(max_to_keep=100)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    # Use the line below to load a checkpoint and resume training
    #saver.restore(sess, 'checkpoints/anna20.ckpt')
    
    n_batches = int(train_x.shape[1]/num_steps)
    iterations = n_batches * epochs
    for e in range(epochs):
        
        # Train network
        new_state = sess.run(model.initial_state)
        loss = 0
        for b, (x, y) in enumerate(get_batch([train_x, train_y], num_steps), 1):
            iteration = e*n_batches + b
            start = time.time()
            feed = {model.inputs: x,
                    model.targets: y,
                    model.keep_prob: 0.5,
                    model.initial_state: new_state}
            batch_loss, new_state, _ = sess.run([model.cost, model.final_state, model.optimizer], 
                                                 feed_dict=feed)
            loss += batch_loss
            end = time.time()
            print('Epoch {}/{} '.format(e+1, epochs),
                  'Iteration {}/{}'.format(iteration, iterations),
                  'Training loss: {:.4f}'.format(loss/b),
                  '{:.4f} sec/batch'.format((end-start)))
        
            
            if (iteration%save_every_n == 0) or (iteration == iterations):
                # Check performance, notice dropout has been set to 1
                val_loss = []
                new_state = sess.run(model.initial_state)
                for x, y in get_batch([val_x, val_y], num_steps):
                    feed = {model.inputs: x,
                            model.targets: y,
                            model.keep_prob: 1.,
                            model.initial_state: new_state}
                    batch_loss, new_state = sess.run([model.cost, model.final_state], feed_dict=feed)
                    val_loss.append(batch_loss)

                print('Validation loss:', np.mean(val_loss),
                      'Saving checkpoint!')
                saver.save(sess, "checkpoints/anna/i{}_l{}_{:.3f}.ckpt".format(iteration, lstm_size, np.mean(val_loss)))
# Out:
# Epoch 1/10  Iteration 1/1780 Training loss: 4.4185 0.2857 sec/batch
# Epoch 1/10  Iteration 2/1780 Training loss: 4.3743 0.0998 sec/batch
# Epoch 1/10  Iteration 3/1780 Training loss: 4.1937 0.1049 sec/batch
# Epoch 1/10  Iteration 4/1780 Training loss: 4.5007 0.1232 sec/batch
# Epoch 1/10  Iteration 5/1780 Training loss: 4.4566 0.1014 sec/batch
# Epoch 1/10  Iteration 6/1780 Training loss: 4.3847 0.1262 sec/batch
# Epoch 1/10  Iteration 7/1780 Training loss: 4.3136 0.0968 sec/batch
# Epoch 1/10  Iteration 8/1780 Training loss: 4.2389 0.1262 sec/batch
# Epoch 1/10  Iteration 9/1780 Training loss: 4.1657 0.1027 sec/batch
# Epoch 1/10  Iteration 10/1780 Training loss: 4.1006 0.1247 sec/batch
# Epoch 1/10  Iteration 11/1780 Training loss: 4.0417 0.0973 sec/batch
# Epoch 1/10  Iteration 12/1780 Training loss: 3.9911 0.1268 sec/batch
# Epoch 1/10  Iteration 13/1780 Training loss: 3.9479 0.0967 sec/batch
# Epoch 1/10  Iteration 14/1780 Training loss: 3.9113 0.1307 sec/batch
# Epoch 1/10  Iteration 15/1780 Training loss: 3.8765 0.0975 sec/batch
# Epoch 1/10  Iteration 16/1780 Training loss: 3.8438 0.1238 sec/batch
# Epoch 1/10  Iteration 17/1780 Training loss: 3.8138 0.0990 sec/batch
# Epoch 1/10  Iteration 18/1780 Training loss: 3.7878 0.1245 sec/batch
# Epoch 1/10  Iteration 19/1780 Training loss: 3.7634 0.0983 sec/batch
# Epoch 1/10  Iteration 20/1780 Training loss: 3.7398 0.1272 sec/batch
# Epoch 1/10  Iteration 21/1780 Training loss: 3.7192 0.0993 sec/batch
# Epoch 1/10  Iteration 22/1780 Training loss: 3.7000 0.1275 sec/batch
# Epoch 1/10  Iteration 23/1780 Training loss: 3.6820 0.0930 sec/batch
# Epoch 1/10  Iteration 24/1780 Training loss: 3.6650 0.1153 sec/batch
# Epoch 1/10  Iteration 25/1780 Training loss: 3.6486 0.1000 sec/batch
# Epoch 1/10  Iteration 26/1780 Training loss: 3.6343 0.1009 sec/batch
# Epoch 1/10  Iteration 27/1780 Training loss: 3.6209 0.1005 sec/batch
# Epoch 1/10  Iteration 28/1780 Training loss: 3.6075 0.1080 sec/batch
# Epoch 1/10  Iteration 29/1780 Training loss: 3.5951 0.0975 sec/batch
# Epoch 3/10  Iteration 360/1780 Training loss: 2.2231 0.1342 sec/batch
# Epoch 3/10  Iteration 361/1780 Training loss: 2.2204 0.1369 sec/batch
# Epoch 3/10  Iteration 362/1780 Training loss: 2.2153 0.1299 sec/batch
# Epoch 3/10  Iteration 363/1780 Training loss: 2.2136 0.0995 sec/batch
# Epoch 3/10  Iteration 364/1780 Training loss: 2.2132 0.0962 sec/batch
# Epoch 3/10  Iteration 365/1780 Training loss: 2.2150 0.0930 sec/batch
# Epoch 3/10  Iteration 366/1780 Training loss: 2.2135 0.1039 sec/batch
# Epoch 3/10  Iteration 367/1780 Training loss: 2.2102 0.0943 sec/batch
# Epoch 3/10  Iteration 368/1780 Training loss: 2.2084 0.0995 sec/batch
# Epoch 3/10  Iteration 369/1780 Training loss: 2.2070 0.0999 sec/batch
# Epoch 3/10  Iteration 370/1780 Training loss: 2.2085 0.0934 sec/batch
# Epoch 3/10  Iteration 371/1780 Training loss: 2.2076 0.1003 sec/batch
# Epoch 3/10  Iteration 372/1780 Training loss: 2.2058 0.1333 sec/batch
# Epoch 3/10  Iteration 373/1780 Training loss: 2.2047 0.1352 sec/batch
# Epoch 3/10  Iteration 374/1780 Training loss: 2.2055 0.1342 sec/batch
# Epoch 3/10  Iteration 375/1780 Training loss: 2.2050 0.1388 sec/batch
# Epoch 3/10  Iteration 376/1780 Training loss: 2.2032 0.1336 sec/batch
# Epoch 3/10  Iteration 377/1780 Training loss: 2.2017 0.1340 sec/batch
# Epoch 3/10  Iteration 378/1780 Training loss: 2.2020 0.1368 sec/batch
# Epoch 3/10  Iteration 379/1780 Training loss: 2.2010 0.1332 sec/batch
# Epoch 3/10  Iteration 380/1780 Training loss: 2.1995 0.1255 sec/batch
# Epoch 3/10  Iteration 381/1780 Training loss: 2.1983 0.0957 sec/batch
# Epoch 3/10  Iteration 382/1780 Training loss: 2.1967 0.1357 sec/batch
# Epoch 3/10  Iteration 383/1780 Training loss: 2.1951 0.1349 sec/batch
# Epoch 3/10  Iteration 384/1780 Training loss: 2.1942 0.1344 sec/batch
# Epoch 3/10  Iteration 385/1780 Training loss: 2.1942 0.1327 sec/batch
# Epoch 3/10  Iteration 386/1780 Training loss: 2.1934 0.0963 sec/batch
# Epoch 3/10  Iteration 387/1780 Training loss: 2.1928 0.0952 sec/batch
# Epoch 3/10  Iteration 388/1780 Training loss: 2.1910 0.0932 sec/batch
# Epoch 3/10  Iteration 389/1780 Training loss: 2.1898 0.1045 sec/batch
# Epoch 3/10  Iteration 390/1780 Training loss: 2.1896 0.0935 sec/batch
# Epoch 3/10  Iteration 391/1780 Training loss: 2.1883 0.0949 sec/batch
# Epoch 3/10  Iteration 392/1780 Training loss: 2.1871 0.1070 sec/batch
# Epoch 3/10  Iteration 393/1780 Training loss: 2.1858 0.0932 sec/batch
# Epoch 3/10  Iteration 394/1780 Training loss: 2.1841 0.0988 sec/batch
# Epoch 3/10  Iteration 395/1780 Training loss: 2.1823 0.1050 sec/batch
# Epoch 3/10  Iteration 396/1780 Training loss: 2.1809 0.0963 sec/batch
# Epoch 3/10  Iteration 397/1780 Training loss: 2.1797 0.0967 sec/batch
# Epoch 3/10  Iteration 398/1780 Training loss: 2.1786 0.1045 sec/batch
# Epoch 3/10  Iteration 399/1780 Training loss: 2.1772 0.0933 sec/batch
# Epoch 3/10  Iteration 400/1780 Training loss: 2.1755 0.1008 sec/batch
# Validation loss: 2.02731 Saving checkpoint!
# Epoch 3/10  Iteration 401/1780 Training loss: 2.1752 0.0933 sec/batch
# Epoch 3/10  Iteration 402/1780 Training loss: 2.1731 0.1205 sec/batch
# Epoch 3/10  Iteration 403/1780 Training loss: 2.1722 0.1348 sec/batch
# Epoch 3/10  Iteration 404/1780 Training loss: 2.1708 0.1342 sec/batch
# Epoch 3/10  Iteration 405/1780 Training loss: 2.1698 0.1385 sec/batch
# Epoch 3/10  Iteration 406/1780 Training loss: 2.1694 0.1306 sec/batch
# Epoch 3/10  Iteration 407/1780 Training loss: 2.1680 0.1278 sec/batch
# Epoch 3/10  Iteration 408/1780 Training loss: 2.1678 0.1350 sec/batch
# Epoch 3/10  Iteration 409/1780 Training loss: 2.1668 0.1354 sec/batch
# Epoch 3/10  Iteration 410/1780 Training loss: 2.1657 0.1374 sec/batch
# Epoch 3/10  Iteration 411/1780 Training loss: 2.1647 0.1358 sec/batch
# Epoch 3/10  Iteration 412/1780 Training loss: 2.1640 0.1039 sec/batch
# Epoch 3/10  Iteration 413/1780 Training loss: 2.1632 0.0937 sec/batch
# Epoch 3/10  Iteration 414/1780 Training loss: 2.1621 0.0934 sec/batch
# Epoch 3/10  Iteration 415/1780 Training loss: 2.1611 0.0966 sec/batch
# Epoch 3/10  Iteration 416/1780 Training loss: 2.1608 0.0979 sec/batch
# Epoch 3/10  Iteration 417/1780 Training loss: 2.1598 0.0948 sec/batch
# Epoch 3/10  Iteration 418/1780 Training loss: 2.1595 0.1139 sec/batch
# Epoch 3/10  Iteration 419/1780 Training loss: 2.1591 0.0948 sec/batch
# Epoch 3/10  Iteration 420/1780 Training loss: 2.1583 0.0993 sec/batch
# Epoch 3/10  Iteration 421/1780 Training loss: 2.1573 0.1002 sec/batch
# Epoch 3/10  Iteration 422/1780 Training loss: 2.1567 0.0990 sec/batch
# Epoch 3/10  Iteration 423/1780 Training loss: 2.1560 0.0986 sec/batch
# Epoch 3/10  Iteration 424/1780 Training loss: 2.1547 0.0982 sec/batch
# Epoch 3/10  Iteration 425/1780 Training loss: 2.1537 0.0935 sec/batch
# Epoch 3/10  Iteration 426/1780 Training loss: 2.1529 0.1002 sec/batch
# Epoch 3/10  Iteration 427/1780 Training loss: 2.1525 0.1000 sec/batch
# Epoch 3/10  Iteration 428/1780 Training loss: 2.1518 0.0977 sec/batch
# Epoch 3/10  Iteration 429/1780 Training loss: 2.1514 0.0965 sec/batch
# Epoch 3/10  Iteration 430/1780 Training loss: 2.1504 0.1032 sec/batch
# Epoch 3/10  Iteration 431/1780 Training loss: 2.1496 0.0944 sec/batch
# Epoch 3/10  Iteration 432/1780 Training loss: 2.1492 0.0960 sec/batch
# Epoch 3/10  Iteration 433/1780 Training loss: 2.1483 0.1031 sec/batch
# Epoch 3/10  Iteration 434/1780 Training loss: 2.1476 0.0946 sec/batch
# Epoch 3/10  Iteration 435/1780 Training loss: 2.1464 0.0951 sec/batch
# Epoch 3/10  Iteration 436/1780 Training loss: 2.1456 0.0974 sec/batch
# Epoch 3/10  Iteration 437/1780 Training loss: 2.1445 0.0957 sec/batch
# Epoch 3/10  Iteration 438/1780 Training loss: 2.1439 0.0969 sec/batch
# Epoch 3/10  Iteration 439/1780 Training loss: 2.1427 0.1019 sec/batch
# Epoch 3/10  Iteration 440/1780 Training loss: 2.1419 0.0979 sec/batch
# Epoch 3/10  Iteration 441/1780 Training loss: 2.1407 0.0954 sec/batch
# Epoch 3/10  Iteration 442/1780 Training loss: 2.1397 0.1016 sec/batch
# Epoch 3/10  Iteration 443/1780 Training loss: 2.1388 0.0974 sec/batch
# Epoch 3/10  Iteration 444/1780 Training loss: 2.1379 0.0956 sec/batch
# Epoch 3/10  Iteration 445/1780 Training loss: 2.1368 0.1028 sec/batch
# Epoch 3/10  Iteration 446/1780 Training loss: 2.1361 0.1186 sec/batch
# Epoch 3/10  Iteration 447/1780 Training loss: 2.1352 0.0970 sec/batch
# Epoch 3/10  Iteration 448/1780 Training loss: 2.1344 0.1268 sec/batch
# Epoch 3/10  Iteration 449/1780 Training loss: 2.1332 0.1000 sec/batch
# Epoch 3/10  Iteration 450/1780 Training loss: 2.1322 0.0941 sec/batch
# Epoch 3/10  Iteration 451/1780 Training loss: 2.1311 0.0963 sec/batch
# Epoch 3/10  Iteration 452/1780 Training loss: 2.1303 0.0967 sec/batch
# Epoch 3/10  Iteration 453/1780 Training loss: 2.1294 0.0994 sec/batch
# Epoch 3/10  Iteration 454/1780 Training loss: 2.1285 0.0942 sec/batch
# Epoch 3/10  Iteration 455/1780 Training loss: 2.1274 0.0997 sec/batch
# Epoch 3/10  Iteration 456/1780 Training loss: 2.1263 0.0952 sec/batch
# Epoch 3/10  Iteration 457/1780 Training loss: 2.1257 0.0943 sec/batch
# Epoch 3/10  Iteration 458/1780 Training loss: 2.1249 0.0955 sec/batch
# Epoch 3/10  Iteration 459/1780 Training loss: 2.1238 0.0961 sec/batch
# Epoch 3/10  Iteration 460/1780 Training loss: 2.1229 0.1004 sec/batch
# Epoch 3/10  Iteration 461/1780 Training loss: 2.1219 0.0988 sec/batch
# Epoch 3/10  Iteration 462/1780 Training loss: 2.1213 0.0993 sec/batch
# Epoch 3/10  Iteration 463/1780 Training loss: 2.1205 0.0961 sec/batch
# Epoch 3/10  Iteration 464/1780 Training loss: 2.1198 0.0975 sec/batch
# Epoch 3/10  Iteration 465/1780 Training loss: 2.1193 0.0969 sec/batch
# Epoch 3/10  Iteration 466/1780 Training loss: 2.1184 0.0978 sec/batch
# Epoch 3/10  Iteration 467/1780 Training loss: 2.1178 0.0977 sec/batch
# Epoch 3/10  Iteration 468/1780 Training loss: 2.1170 0.0949 sec/batch
# Epoch 3/10  Iteration 469/1780 Training loss: 2.1162 0.0959 sec/batch
# Epoch 3/10  Iteration 470/1780 Training loss: 2.1153 0.0992 sec/batch
# Epoch 3/10  Iteration 471/1780 Training loss: 2.1144 0.0995 sec/batch
# Epoch 3/10  Iteration 472/1780 Training loss: 2.1134 0.0989 sec/batch
# Epoch 3/10  Iteration 473/1780 Training loss: 2.1127 0.1029 sec/batch
# Epoch 3/10  Iteration 474/1780 Training loss: 2.1119 0.1046 sec/batch
# Epoch 3/10  Iteration 475/1780 Training loss: 2.1111 0.0985 sec/batch
# Epoch 3/10  Iteration 476/1780 Training loss: 2.1105 0.0976 sec/batch
# Epoch 3/10  Iteration 477/1780 Training loss: 2.1098 0.1000 sec/batch
# Epoch 3/10  Iteration 478/1780 Training loss: 2.1090 0.1320 sec/batch
# Epoch 3/10  Iteration 479/1780 Training loss: 2.1082 0.1072 sec/batch
# Epoch 3/10  Iteration 480/1780 Training loss: 2.1077 0.1052 sec/batch
# Epoch 3/10  Iteration 481/1780 Training loss: 2.1069 0.1051 sec/batch
# Epoch 3/10  Iteration 482/1780 Training loss: 2.1060 0.1024 sec/batch
# Epoch 3/10  Iteration 483/1780 Training loss: 2.1054 0.1065 sec/batch
# Epoch 3/10  Iteration 484/1780 Training loss: 2.1048 0.1065 sec/batch
# Epoch 3/10  Iteration 485/1780 Training loss: 2.1041 0.1286 sec/batch
# Epoch 3/10  Iteration 486/1780 Training loss: 2.1035 0.1174 sec/batch
# Epoch 3/10  Iteration 487/1780 Training loss: 2.1026 0.1049 sec/batch
# Epoch 3/10  Iteration 488/1780 Training loss: 2.1016 0.1012 sec/batch
# Epoch 3/10  Iteration 489/1780 Training loss: 2.1011 0.1317 sec/batch
# Epoch 3/10  Iteration 490/1780 Training loss: 2.1005 0.1100 sec/batch
# Epoch 3/10  Iteration 491/1780 Training loss: 2.0998 0.1031 sec/batch
# Epoch 3/10  Iteration 492/1780 Training loss: 2.0992 0.1161 sec/batch
# Epoch 3/10  Iteration 493/1780 Training loss: 2.0986 0.1082 sec/batch
# Epoch 3/10  Iteration 494/1780 Training loss: 2.0979 0.1036 sec/batch
# Epoch 3/10  Iteration 495/1780 Training loss: 2.0975 0.1164 sec/batch
# Epoch 3/10  Iteration 496/1780 Training loss: 2.0967 0.1002 sec/batch
# Epoch 3/10  Iteration 497/1780 Training loss: 2.0963 0.0975 sec/batch
# Epoch 3/10  Iteration 498/1780 Training loss: 2.0956 0.1011 sec/batch
# Epoch 3/10  Iteration 499/1780 Training loss: 2.0949 0.0999 sec/batch
# Epoch 3/10  Iteration 500/1780 Training loss: 2.0942 0.0937 sec/batch
# Epoch 3/10  Iteration 501/1780 Training loss: 2.0935 0.0994 sec/batch
# Epoch 3/10  Iteration 502/1780 Training loss: 2.0929 0.0935 sec/batch
# Epoch 3/10  Iteration 503/1780 Training loss: 2.0923 0.0987 sec/batch
# Epoch 3/10  Iteration 504/1780 Training loss: 2.0918 0.0994 sec/batch
# Epoch 3/10  Iteration 505/1780 Training loss: 2.0912 0.0977 sec/batch
# Epoch 3/10  Iteration 506/1780 Training loss: 2.0904 0.0965 sec/batch
# Epoch 3/10  Iteration 507/1780 Training loss: 2.0898 0.0995 sec/batch
# Epoch 3/10  Iteration 508/1780 Training loss: 2.0894 0.0992 sec/batch
# Epoch 3/10  Iteration 509/1780 Training loss: 2.0888 0.1315 sec/batch
# Epoch 3/10  Iteration 510/1780 Training loss: 2.0883 0.1377 sec/batch
# Epoch 3/10  Iteration 511/1780 Training loss: 2.0876 0.1068 sec/batch
# Epoch 3/10  Iteration 512/1780 Training loss: 2.0869 0.0991 sec/batch
# Epoch 3/10  Iteration 513/1780 Training loss: 2.0862 0.1006 sec/batch
# Epoch 3/10  Iteration 514/1780 Training loss: 2.0856 0.0948 sec/batch
# Epoch 3/10  Iteration 515/1780 Training loss: 2.0847 0.0952 sec/batch
# Epoch 3/10  Iteration 516/1780 Training loss: 2.0843 0.0954 sec/batch
# Epoch 3/10  Iteration 517/1780 Training loss: 2.0838 0.0950 sec/batch
# Epoch 3/10  Iteration 518/1780 Training loss: 2.0831 0.1011 sec/batch
# Epoch 3/10  Iteration 519/1780 Training loss: 2.0826 0.0947 sec/batch
# Epoch 3/10  Iteration 520/1780 Training loss: 2.0820 0.0998 sec/batch
# Epoch 3/10  Iteration 521/1780 Training loss: 2.0813 0.0945 sec/batch
# Epoch 3/10  Iteration 522/1780 Training loss: 2.0806 0.0964 sec/batch
# Epoch 3/10  Iteration 523/1780 Training loss: 2.0801 0.0957 sec/batch
# Epoch 3/10  Iteration 524/1780 Training loss: 2.0797 0.0999 sec/batch
# Epoch 3/10  Iteration 525/1780 Training loss: 2.0791 0.1054 sec/batch
# Epoch 3/10  Iteration 526/1780 Training loss: 2.0784 0.1224 sec/batch
# Epoch 3/10  Iteration 527/1780 Training loss: 2.0777 0.1047 sec/batch
# Epoch 3/10  Iteration 528/1780 Training loss: 2.0771 0.0983 sec/batch
# Epoch 3/10  Iteration 529/1780 Training loss: 2.0765 0.1002 sec/batch
# Epoch 3/10  Iteration 530/1780 Training loss: 2.0760 0.0970 sec/batch
# Epoch 3/10  Iteration 531/1780 Training loss: 2.0755 0.0986 sec/batch
# Epoch 3/10  Iteration 532/1780 Training loss: 2.0748 0.0980 sec/batch
# Epoch 3/10  Iteration 533/1780 Training loss: 2.0741 0.0967 sec/batch
# Epoch 3/10  Iteration 534/1780 Training loss: 2.0735 0.1007 sec/batch
# Epoch 4/10  Iteration 535/1780 Training loss: 2.0412 0.1375 sec/batch
# Epoch 4/10  Iteration 536/1780 Training loss: 1.9908 0.1351 sec/batch
# Epoch 4/10  Iteration 537/1780 Training loss: 1.9749 0.1345 sec/batch
# Epoch 4/10  Iteration 538/1780 Training loss: 1.9676 0.1343 sec/batch
# Epoch 4/10  Iteration 539/1780 Training loss: 1.9637 0.1374 sec/batch
# Epoch 4/10  Iteration 540/1780 Training loss: 1.9537 0.1240 sec/batch
# Epoch 4/10  Iteration 541/1780 Training loss: 1.9549 0.1383 sec/batch
# Epoch 4/10  Iteration 542/1780 Training loss: 1.9539 0.1344 sec/batch
# Epoch 4/10  Iteration 543/1780 Training loss: 1.9571 0.1378 sec/batch
# Epoch 4/10  Iteration 617/1780 Training loss: 1.9116 0.1007 sec/batch
# Epoch 4/10  Iteration 618/1780 Training loss: 1.9111 0.1006 sec/batch
# Epoch 4/10  Iteration 619/1780 Training loss: 1.9102 0.0995 sec/batch
# Epoch 4/10  Iteration 620/1780 Training loss: 1.9094 0.0956 sec/batch
# Epoch 4/10  Iteration 621/1780 Training loss: 1.9089 0.0981 sec/batch
# Epoch 4/10  Iteration 622/1780 Training loss: 1.9081 0.0960 sec/batch
# Epoch 4/10  Iteration 623/1780 Training loss: 1.9072 0.0990 sec/batch
# Epoch 4/10  Iteration 624/1780 Training loss: 1.9069 0.1000 sec/batch
# Epoch 4/10  Iteration 625/1780 Training loss: 1.9061 0.0984 sec/batch
# Epoch 4/10  Iteration 626/1780 Training loss: 1.9055 0.0932 sec/batch
# Epoch 4/10  Iteration 627/1780 Training loss: 1.9046 0.0992 sec/batch
# Epoch 4/10  Iteration 628/1780 Training loss: 1.9037 0.0935 sec/batch
# Epoch 4/10  Iteration 629/1780 Training loss: 1.9029 0.0953 sec/batch
# Epoch 4/10  Iteration 630/1780 Training loss: 1.9024 0.0985 sec/batch
# Epoch 4/10  Iteration 631/1780 Training loss: 1.9019 0.0965 sec/batch
# Epoch 4/10  Iteration 632/1780 Training loss: 1.9010 0.0972 sec/batch
# Epoch 4/10  Iteration 633/1780 Training loss: 1.9002 0.1005 sec/batch
# Epoch 4/10  Iteration 634/1780 Training loss: 1.8994 0.0953 sec/batch
# Epoch 4/10  Iteration 635/1780 Training loss: 1.8989 0.0975 sec/batch
# Epoch 4/10  Iteration 636/1780 Training loss: 1.8985 0.0956 sec/batch
# Epoch 4/10  Iteration 637/1780 Training loss: 1.8979 0.0944 sec/batch
# Epoch 4/10  Iteration 638/1780 Training loss: 1.8972 0.0955 sec/batch
# Epoch 4/10  Iteration 639/1780 Training loss: 1.8965 0.0952 sec/batch
# Epoch 4/10  Iteration 640/1780 Training loss: 1.8960 0.1023 sec/batch
# Epoch 4/10  Iteration 641/1780 Training loss: 1.8955 0.1072 sec/batch
# Epoch 4/10  Iteration 642/1780 Training loss: 1.8950 0.0959 sec/batch
# Epoch 4/10  Iteration 643/1780 Training loss: 1.8947 0.0967 sec/batch
# Epoch 4/10  Iteration 644/1780 Training loss: 1.8942 0.0950 sec/batch
# Epoch 4/10  Iteration 645/1780 Training loss: 1.8937 0.0994 sec/batch
# Epoch 4/10  Iteration 646/1780 Training loss: 1.8931 0.0968 sec/batch
# Epoch 4/10  Iteration 647/1780 Training loss: 1.8925 0.0970 sec/batch
# Epoch 4/10  Iteration 648/1780 Training loss: 1.8920 0.0935 sec/batch
# Epoch 4/10  Iteration 649/1780 Training loss: 1.8913 0.0986 sec/batch
# Epoch 4/10  Iteration 650/1780 Training loss: 1.8906 0.0985 sec/batch
# Epoch 4/10  Iteration 651/1780 Training loss: 1.8902 0.0963 sec/batch
# Epoch 4/10  Iteration 652/1780 Training loss: 1.8896 0.0981 sec/batch
# Epoch 4/10  Iteration 653/1780 Training loss: 1.8891 0.0975 sec/batch
# Epoch 4/10  Iteration 654/1780 Training loss: 1.8887 0.1074 sec/batch
# Epoch 4/10  Iteration 655/1780 Training loss: 1.8883 0.0974 sec/batch
# Epoch 4/10  Iteration 656/1780 Training loss: 1.8876 0.0954 sec/batch
# Epoch 4/10  Iteration 657/1780 Training loss: 1.8869 0.0974 sec/batch
# Epoch 4/10  Iteration 658/1780 Training loss: 1.8866 0.1303 sec/batch
# Epoch 4/10  Iteration 659/1780 Training loss: 1.8861 0.1175 sec/batch
# Epoch 4/10  Iteration 660/1780 Training loss: 1.8852 0.0955 sec/batch
# Epoch 4/10  Iteration 661/1780 Training loss: 1.8850 0.0956 sec/batch
# Epoch 4/10  Iteration 662/1780 Training loss: 1.8846 0.0998 sec/batch
# Epoch 4/10  Iteration 663/1780 Training loss: 1.8840 0.0939 sec/batch
# Epoch 4/10  Iteration 664/1780 Training loss: 1.8836 0.1009 sec/batch
# Epoch 4/10  Iteration 665/1780 Training loss: 1.8829 0.0950 sec/batch
# Epoch 4/10  Iteration 666/1780 Training loss: 1.8822 0.0972 sec/batch
# Epoch 4/10  Iteration 667/1780 Training loss: 1.8818 0.1178 sec/batch
# Epoch 4/10  Iteration 668/1780 Training loss: 1.8815 0.1388 sec/batch
# Epoch 4/10  Iteration 669/1780 Training loss: 1.8810 0.1370 sec/batch
# Epoch 4/10  Iteration 670/1780 Training loss: 1.8807 0.1344 sec/batch
# Epoch 4/10  Iteration 671/1780 Training loss: 1.8803 0.1016 sec/batch
# Epoch 4/10  Iteration 672/1780 Training loss: 1.8800 0.1031 sec/batch
# Epoch 4/10  Iteration 673/1780 Training loss: 1.8798 0.0962 sec/batch
# Epoch 4/10  Iteration 674/1780 Training loss: 1.8793 0.0954 sec/batch
# Epoch 4/10  Iteration 675/1780 Training loss: 1.8792 0.0989 sec/batch
# Epoch 4/10  Iteration 676/1780 Training loss: 1.8787 0.0939 sec/batch
# Epoch 4/10  Iteration 677/1780 Training loss: 1.8782 0.0957 sec/batch
# Epoch 4/10  Iteration 678/1780 Training loss: 1.8778 0.1009 sec/batch
# Epoch 4/10  Iteration 679/1780 Training loss: 1.8773 0.1018 sec/batch
# Epoch 4/10  Iteration 680/1780 Training loss: 1.8769 0.1002 sec/batch
# Epoch 4/10  Iteration 681/1780 Training loss: 1.8766 0.0939 sec/batch
# Epoch 4/10  Iteration 682/1780 Training loss: 1.8763 0.0982 sec/batch
# Epoch 4/10  Iteration 683/1780 Training loss: 1.8759 0.0951 sec/batch
# Epoch 4/10  Iteration 684/1780 Training loss: 1.8754 0.0940 sec/batch
# Epoch 4/10  Iteration 685/1780 Training loss: 1.8748 0.0959 sec/batch
# ...
# Epoch 9/10  Iteration 1560/1780 Training loss: 1.4481 0.0956 sec/batch
# Epoch 9/10  Iteration 1561/1780 Training loss: 1.4481 0.0965 sec/batch
# Epoch 9/10  Iteration 1562/1780 Training loss: 1.4481 0.0937 sec/batch
# Epoch 9/10  Iteration 1563/1780 Training loss: 1.4480 0.0984 sec/batch
# Epoch 10/10  Iteration 1743/1780 Training loss: 1.4068 0.0974 sec/batch
# Epoch 10/10  Iteration 1744/1780 Training loss: 1.4067 0.0997 sec/batch
# Epoch 10/10  Iteration 1745/1780 Training loss: 1.4066 0.1020 sec/batch
# Epoch 10/10  Iteration 1746/1780 Training loss: 1.4067 0.0984 sec/batch
# Epoch 10/10  Iteration 1747/1780 Training loss: 1.4065 0.0950 sec/batch
# Epoch 10/10  Iteration 1748/1780 Training loss: 1.4066 0.0951 sec/batch
# Epoch 10/10  Iteration 1749/1780 Training loss: 1.4065 0.0995 sec/batch
# Epoch 10/10  Iteration 1750/1780 Training loss: 1.4067 0.0957 sec/batch
# Epoch 10/10  Iteration 1751/1780 Training loss: 1.4067 0.0953 sec/batch
# Epoch 10/10  Iteration 1752/1780 Training loss: 1.4065 0.0977 sec/batch
# Epoch 10/10  Iteration 1753/1780 Training loss: 1.4062 0.0986 sec/batch
# Epoch 10/10  Iteration 1754/1780 Training loss: 1.4060 0.0940 sec/batch
# Epoch 10/10  Iteration 1755/1780 Training loss: 1.4060 0.1002 sec/batch
# Epoch 10/10  Iteration 1756/1780 Training loss: 1.4059 0.0949 sec/batch
# Epoch 10/10  Iteration 1757/1780 Training loss: 1.4058 0.0983 sec/batch
# Epoch 10/10  Iteration 1758/1780 Training loss: 1.4057 0.0985 sec/batch
# Epoch 10/10  Iteration 1759/1780 Training loss: 1.4056 0.0954 sec/batch
# Epoch 10/10  Iteration 1760/1780 Training loss: 1.4055 0.0939 sec/batch
# Epoch 10/10  Iteration 1761/1780 Training loss: 1.4052 0.0952 sec/batch
# Epoch 10/10  Iteration 1762/1780 Training loss: 1.4052 0.0997 sec/batch
# Epoch 10/10  Iteration 1763/1780 Training loss: 1.4053 0.0962 sec/batch
# Epoch 10/10  Iteration 1764/1780 Training loss: 1.4051 0.0998 sec/batch
# Epoch 10/10  Iteration 1765/1780 Training loss: 1.4050 0.0983 sec/batch
# Epoch 10/10  Iteration 1766/1780 Training loss: 1.4049 0.0996 sec/batch
# Epoch 10/10  Iteration 1767/1780 Training loss: 1.4049 0.1025 sec/batch
# Epoch 10/10  Iteration 1768/1780 Training loss: 1.4047 0.0938 sec/batch
# Epoch 10/10  Iteration 1769/1780 Training loss: 1.4048 0.0970 sec/batch
# Epoch 10/10  Iteration 1770/1780 Training loss: 1.4051 0.0989 sec/batch
# Epoch 10/10  Iteration 1771/1780 Training loss: 1.4050 0.1000 sec/batch
# Epoch 10/10  Iteration 1772/1780 Training loss: 1.4050 0.0986 sec/batch
# Epoch 10/10  Iteration 1773/1780 Training loss: 1.4048 0.0951 sec/batch
# Epoch 10/10  Iteration 1774/1780 Training loss: 1.4045 0.0941 sec/batch
# Epoch 10/10  Iteration 1775/1780 Training loss: 1.4046 0.0960 sec/batch
# Epoch 10/10  Iteration 1776/1780 Training loss: 1.4045 0.1066 sec/batch
# Epoch 10/10  Iteration 1777/1780 Training loss: 1.4045 0.1001 sec/batch
# Epoch 10/10  Iteration 1778/1780 Training loss: 1.4043 0.0936 sec/batch
# Epoch 10/10  Iteration 1779/1780 Training loss: 1.4041 0.1001 sec/batch
# Epoch 10/10  Iteration 1780/1780 Training loss: 1.4041 0.0940 sec/batch
# Validation loss: 1.26885 Saving checkpoint!

# %%
tf.train.get_checkpoint_state('checkpoints/anna')
# Out:
# model_checkpoint_path: "checkpoints/anna/i3560_l512_1.122.ckpt"
# all_model_checkpoint_paths: "checkpoints/anna/i200_l512_2.432.ckpt"
# all_model_checkpoint_paths: "checkpoints/anna/i400_l512_1.980.ckpt"
# all_model_checkpoint_paths: "checkpoints/anna/i600_l512_1.750.ckpt"
# all_model_checkpoint_paths: "checkpoints/anna/i800_l512_1.595.ckpt"
# all_model_checkpoint_paths: "checkpoints/anna/i1000_l512_1.484.ckpt"
# all_model_checkpoint_paths: "checkpoints/anna/i1200_l512_1.407.ckpt"
# all_model_checkpoint_paths: "checkpoints/anna/i1400_l512_1.349.ckpt"
# all_model_checkpoint_paths: "checkpoints/anna/i1600_l512_1.292.ckpt"
# all_model_checkpoint_paths: "checkpoints/anna/i1800_l512_1.255.ckpt"
# all_model_checkpoint_paths: "checkpoints/anna/i2000_l512_1.224.ckpt"
# all_model_checkpoint_paths: "checkpoints/anna/i2200_l512_1.204.ckpt"
# all_model_checkpoint_paths: "checkpoints/anna/i2400_l512_1.187.ckpt"
# all_model_checkpoint_paths: "checkpoints/anna/i2600_l512_1.172.ckpt"
# all_model_checkpoint_paths: "checkpoints/anna/i2800_l512_1.160.ckpt"
# all_model_checkpoint_paths: "checkpoints/anna/i3000_l512_1.148.ckpt"
# all_model_checkpoint_paths: "checkpoints/anna/i3200_l512_1.137.ckpt"
# all_model_checkpoint_paths: "checkpoints/anna/i3400_l512_1.129.ckpt"
# all_model_checkpoint_paths: "checkpoints/anna/i3560_l512_1.122.ckpt"

# %% [markdown]
# ## Sampling
#
# Now that the network is trained, we'll can use it to generate new text. The idea is that we pass in a character, then the network will predict the next character. We can use the new one, to predict the next one. And we keep doing this to generate all new text. I also included some functionality to prime the network with some text by passing in a string and building up a state from that.
#
# The network gives us predictions for each character. To reduce noise and make things a little less random, I'm going to only choose a new character from the top N most likely characters.

# %%
def pick_top_n(preds, vocab_size, top_n=5):
    p = np.squeeze(preds)
    p[np.argsort(p)[:-top_n]] = 0
    p = p / np.sum(p)
    c = np.random.choice(vocab_size, 1, p=p)[0]
    return c

# %%
def sample(checkpoint, n_samples, lstm_size, vocab_size, prime="The "):
    prime = "Far"
    samples = [c for c in prime]
    model = build_rnn(vocab_size, lstm_size=lstm_size, sampling=True)
    saver = tf.train.Saver()
    with tf.Session() as sess:
        saver.restore(sess, checkpoint)
        new_state = sess.run(model.initial_state)
        for c in prime:
            x = np.zeros((1, 1))
            x[0,0] = vocab_to_int[c]
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.preds, model.final_state], 
                                         feed_dict=feed)

        c = pick_top_n(preds, len(vocab))
        samples.append(int_to_vocab[c])

        for i in range(n_samples):
            x[0,0] = c
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.preds, model.final_state], 
                                         feed_dict=feed)

            c = pick_top_n(preds, len(vocab))
            samples.append(int_to_vocab[c])
        
    return ''.join(samples)

# %%
checkpoint = "checkpoints/anna/i3560_l512_1.122.ckpt"
samp = sample(checkpoint, 2000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# Farlathit that if had so
# like it that it were. He could not trouble to his wife, and there was
# anything in them of the side of his weaky in the creature at his forteren
# to him.
#
# "What is it? I can't bread to those," said Stepan Arkadyevitch. "It's not
# my children, and there is an almost this arm, true it mays already,
# and tell you what I have say to you, and was not looking at the peasant,
# why is, I don't know him out, and she doesn't speak to me immediately, as
# you would say the countess and the more frest an angelembre, and time and
# things's silent, but I was not in my stand that is in my head. But if he
# say, and was so feeling with his soul. A child--in his soul of his
# soul of his soul. He should not see that any of that sense of. Here he
# had not been so composed and to speak for as in a whole picture, but
# all the setting and her excellent and society, who had been delighted
# and see to anywing had been being troed to thousand words on them,
# we liked him.
#
# That set in her money at the table, he came into the party. The capable
# of his she could not be as an old composure.
#
# "That's all something there will be down becime by throe is
# such a silent, as in a countess, I should state it out and divorct.
# The discussion is not for me. I was that something was simply they are
# all three manshess of a sensitions of mind it all."
#
# "No," he thought, shouted and lifting his soul. "While it might see your
# honser and she, I could burst. And I had been a midelity. And I had a
# marnief are through the countess," he said, looking at him, a chosing
# which they had been carried out and still solied, and there was a sen that
# was to be completely, and that this matter of all the seconds of it, and
# a concipation were to her husband, who came up and conscaously, that he
# was not the station. All his fourse she was always at the country,,
# to speak oft, and though they were to hear the delightful throom and
# whether they came towards the morning, and his living and a coller and
# hold--the children.

# %%
checkpoint = "checkpoints/anna/i200_l512_2.432.ckpt"
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# Farnt him oste wha sorind thans tout thint asd an sesand an hires on thime sind thit aled, ban thand and out hore as the ter hos ton ho te that, was tis tart al the hand sostint him sore an tit an son thes, win he se ther san ther hher tas tarereng,.
#
# Anl at an ades in ond hesiln, ad hhe torers teans, wast tar arering tho this sos alten sorer has hhas an siton ther him he had sin he ard ate te anling the sosin her ans and
# arins asd and ther ale te tot an tand tanginge wath and ho ald, so sot th asend sat hare sother horesinnd, he hesense wing ante her so tith tir sherinn, anded and to the toul anderin he sorit he torsith she se atere an ting ot hand and thit hhe so the te wile har
# ens ont in the sersise, and we he seres tar aterer, to ato tat or has he he wan ton here won and sen heren he sosering, to to theer oo adent har herere the wosh oute, was serild ward tous hed astend..
#
# I's sint on alt in har tor tit her asd hade shithans ored he talereng an soredendere tim tot hees. Tise sor and

# %%
checkpoint = "checkpoints/anna/i600_l512_1.750.ckpt"
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# Fard as astice her said he celatice of to seress in the raice, and to be the some and sere allats to that said to that the sark and a cast a the wither ald the pacinesse of her had astition, he said to the sount as she west at hissele. Af the cond it he was a fact onthis astisarianing.
#
#
# "Or a ton to to be that's a more at aspestale as the sont of anstiring as
# thours and trey.
#
# The same wo dangring the
# raterst, who sore and somethy had ast out an of his book. "We had's beane were that, and a morted a thay he had to tere. Then to
# her homent andertersed his his ancouted to the pirsted, the soution for of the pirsice inthirgest and stenciol, with the hard and and
# a colrice of to be oneres,
# the song to this anderssad.
# The could ounterss the said to serom of
# soment a carsed of sheres of she
# torded
# har and want in their of hould, but
# her told in that in he tad a the same to her. Serghing an her has and with the seed, and the camt ont his about of the
# sail, the her then all houg ant or to hus to

# %%
checkpoint = "checkpoints/anna/i1000_l512_1.484.ckpt"
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# Farrat, his felt has at it.
#
# "When the pose ther hor exceed
# to his sheant was," weat a sime of his sounsed. The coment and the facily that which had began terede a marilicaly whice whether the pose of his hand, at she was alligated herself the same on she had to
# taiking to his forthing and streath how to hand
# began in a lang at some at it, this he cholded not set all her. "Wo love that is setthing. Him anstering as seen that."
#
# "Yes in the man that say the mare a crances is it?" said Sergazy Ivancatching. "You doon think were somether is ifficult of a mone of
# though the most at the countes that the
# mean on the come to say the most, to
# his feesing of
# a man she, whilo he
# sained and well, that he would still at to said. He wind at his for the sore in the most
# of hoss and almoved to see him. They have betine the sumper into at he his stire, and what he was that at the so steate of the
# sound, and shin should have a geest of shall feet on the conderation to she had been at that imporsing the dre
