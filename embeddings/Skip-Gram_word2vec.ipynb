# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter

word_freq = dict(Counter(int_words))

total_count = len(int_words)

subprobs = {w: 1 - np.sqrt(1e-5/(v /total_count)) for w, v in word_freq.items()}

## Your code here
train_words = [w for w in int_words if np.random.rand() > subprobs[w]]

len(train_words) / len(int_words)
# Out:
# 0.27734957239844926

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, 1+window_size)
    start = idx - R if idx - R > 0 else 0
    end = idx + R + 1
    return set(words[start:idx] +  words[(idx+1):end])

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.01))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, 
                                      softmax_b,
                                      labels, 
                                      embed,
                                      n_sampled,
                                      n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/nn_impl.py:1310: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-13-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
#!mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.4108 0.0207 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.3437 0.0172 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.2641 0.0179 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.3569 0.0178 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.2836 0.0177 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.2456 0.0176 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.1816 0.0172 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.1003 0.0172 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.9648 0.0178 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.8764 0.0175 sec/batch
# Nearest to than: hooker, london, christians, threat, contains, edward, rejected, renewed,
# Nearest to their: option, highly, does, hopping, available, chaplin, blew, deposited,
# Nearest to more: fastest, administration, puts, barca, questions, justice, influx, quick,
# Nearest to four: lose, faster, whenever, scotland, passages, pronunciation, imperial, canada,
# Nearest to all: term, kinsman, soil, footage, converts, scripture, flaws, white,
# Nearest to nine: advocacy, hollies, jurisdiction, habitats, estampie, eight, host, unequivocally,
# Nearest to if: lundy, received, additionally, everyday, travel, soviet, affix, disciplined,
# Nearest to where: revenues, lieutenant, objection, find, debates, standard, outright, american,
# Nearest to test: democr, hyland, themselves, premiers, cuyp, ceding, manifest, sold,
# Nearest to square: bordered, incarnations, manipulation, imply, religions, journalists, orphaned, does,
# Nearest to question: xenophon, redress, hebrew, overhead, downplays, pale, heracleidae, opening,
# Nearest to versions: contributions, us, upon, sharp, running, kept, entered, limits,
# Nearest to derived: red, haunting, write, barbarians, fest, kept, mammals, educators,
# Nearest to orthodox: nami, bobble, recognition, prognosis, xn, parade, suprarenal, pound,
# Nearest to discovered: view, up, corvus, frontal, categories, hitchhiking, waddington, panel,
# Nearest to mathematics: composition, madrid, aswan, unauthorized, younger, plateau, auxiliary, thessalian,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.9002 0.0184 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.7828 0.0173 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.7674 0.0176 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.7505 0.0179 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.7193 0.0173 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.6974 0.0172 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.6964 0.0171 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.7349 0.0173 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.6986 0.0174 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.7163 0.0173 sec/batch
# Nearest to than: hooker, lilac, croatian, quarterbacks, renewed, barcode, cryptologia, contains,
# Nearest to their: option, chaplin, hopping, deposited, navel, blew, customers, fearless,
# Nearest to more: barca, puts, needlework, administration, fastest, insecticides, undeniably, hemophilia,
# Nearest to four: seven, tutorials, herald, untie, hurley, fiesta, scotland, canada,
# Nearest to all: kinsman, term, footage, converts, priestly, scripture, soil, layered,
# Nearest to nine: singer, jurisdiction, eight, unequivocally, dancer, six, advocacy, robb,
# Nearest to if: lundy, rarity, affix, polytechnic, disciplined, mejia, everyday, additionally,
# Nearest to where: revenues, debates, objection, europa, neopagans, farah, competing, criticizes,
# Nearest to test: premiers, hyland, colleague, manifest, haarlem, democr, cordell, macro,
# Nearest to square: bordered, submission, imply, manipulation, assist, intrinsic, mutinied, farewell,
# Nearest to question: xenophon, redress, downplays, hebrew, similarity, vapour, oriented, uncut,
# Nearest to versions: contributions, yury, headlining, scientologists, disciplined, abbey, ekg, calvinists,
# Nearest to derived: fest, haunting, barbarians, red, computationally, orbit, evangelicals, chinaman,
# Nearest to orthodox: nami, bobble, xn, isabella, recognition, conscripts, stern, prognosis,
# Nearest to discovered: corvus, view, hitchhiking, frontal, solstice, up, waddington, categories,
# Nearest to mathematics: composition, madrid, unauthorized, aswan, plateau, doorways, hikers, auxiliary,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.6686 0.0181 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.6740 0.0170 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.6414 0.0173 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.6719 0.0171 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.6169 0.0172 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.6286 0.0172 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.6395 0.0173 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.5952 0.0170 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.5993 0.0171 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.6503 0.0180 sec/batch
# Nearest to than: hooker, lilac, barcode, quarterbacks, cryptologia, arabesque, croatian, beauregard,
# Nearest to their: fearless, option, chaplin, deposited, navel, hopping, sacrifices, customers,
# Nearest to more: barca, needlework, puts, lash, insecticides, hemophilia, heals, fastest,
# Nearest to four: seven, herald, tutorials, hurley, canada, untie, chee, trema,
# Nearest to all: kinsman, term, footage, priestly, muds, eurosceptic, determinants, scripture,
# Nearest to nine: singer, unequivocally, jurisdiction, eight, natalie, estampie, extrinsic, meyer,
# Nearest to if: lundy, rarity, affix, commonalities, deepen, palettes, theorem, polytechnic,
# Nearest to where: neopagans, revenues, criticizes, farah, objection, recurs, europa, debates,
# Nearest to test: premiers, cordell, hyland, culling, haarlem, colleague, thom, manifest,
# Nearest to square: bordered, orphaned, mutinied, farewell, bicycles, imply, submission, intrinsic,
# Nearest to question: xenophon, redress, vapour, hebrew, anisotropic, downplays, heracleidae, invariants,
# Nearest to versions: yury, scientologists, headlining, ekg, contributions, abbey, knoppix, parke,
# Nearest to derived: fest, barbarians, haunting, computationally, chinaman, evangelicals, orbit, subotnick,
# Nearest to orthodox: nami, bobble, isabella, vigor, xn, decoy, barometer, barbiturate,
# Nearest to discovered: corvus, hitchhiking, view, waddington, frontal, solstice, trammell, consequent,
# Nearest to mathematics: doorways, composition, papias, madrid, aswan, unauthorized, thessalian, ndel,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.6163 0.0184 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.6177 0.0181 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.5839 0.0183 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.5404 0.0178 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.5744 0.0172 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.5332 0.0174 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.5504 0.0174 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.5755 0.0171 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.5740 0.0173 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.5100 0.0173 sec/batch
# Nearest to than: lilac, hooker, cryptologia, beauregard, arabesque, noblesse, barcode, journeyman,
# Nearest to their: deposited, fearless, navel, option, pasha, sacrifices, chaplin, supplication,
# Nearest to more: needlework, puts, barca, lash, insecticides, hemophilia, tefillin, regressive,
# Nearest to four: seven, herald, chee, canada, hurley, untie, tutorials, trema,
# Nearest to all: kinsman, term, footage, eurosceptic, priestly, muds, determinants, converts,
# Nearest to nine: singer, unequivocally, estampie, extrinsic, natalie, constitutionally, meyer, katherine,
# Nearest to if: rarity, lundy, theorem, commonalities, deepen, affix, palettes, empiricists,
# Nearest to where: objection, farah, criticizes, neopagans, revenues, europa, recurs, debates,
# Nearest to test: culling, cordell, premiers, hyland, haarlem, wagers, oblivious, macro,
# Nearest to square: bordered, mutinied, orphaned, andaman, bicycles, schiphol, nuisance, hobbled,
# Nearest to question: xenophon, redress, vapour, hebrew, invariants, downplays, chalcedonians, tycho,
# Nearest to versions: yury, scientologists, headlining, ekg, knoppix, contributions, running, parke,
# Nearest to derived: fest, haunting, evangelicals, barbarians, computationally, subotnick, orbit, chinaman,
# Nearest to orthodox: nami, bobble, vigor, isabella, decoy, xn, attest, barometer,
# Nearest to discovered: corvus, hitchhiking, waddington, solstice, view, frontal, trammell, protecting,
# Nearest to mathematics: doorways, composition, papias, aswan, madrid, iota, thessalian, ndel,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.5288 0.0181 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.5326 0.0175 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.4528 0.0175 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.4647 0.0175 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.4764 0.0175 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.4900 0.0171 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.4388 0.0132 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.4228 0.0171 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.3577 0.0173 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.3533 0.0173 sec/batch
# Nearest to than: noblesse, lilac, cryptologia, journeyman, arabesque, barcode, operated, hooker,
# Nearest to their: deposited, navel, fearless, pasha, option, sacrifices, supplication, hopping,
# Nearest to more: needlework, puts, lash, barca, hemophilia, regressive, tefillin, insecticides,
# Nearest to four: chee, seven, untie, hurley, herald, tutorials, fiesta, trema,
# Nearest to all: kinsman, term, muds, footage, eurosceptic, converts, priestly, devoiced,
# Nearest to nine: singer, unequivocally, estampie, extrinsic, natalie, hollies, microchip, tw,
# Nearest to if: theorem, lundy, rarity, affix, deepen, urbane, impermanence, palettes,
# Nearest to where: criticizes, farah, shunning, objection, neopagans, recurs, revenues, debates,
# Nearest to test: cordell, premiers, hyland, culling, haarlem, macro, extremism, oblivious,
# Nearest to square: bordered, andaman, schiphol, orphaned, bicycles, mutinied, hobbled, serif,
# Nearest to question: xenophon, redress, invariants, hebrew, vapour, validity, chalcedonians, downplays,
# Nearest to versions: yury, scientologists, headlining, running, ekg, knoppix, contributions, crest,
# Nearest to derived: fest, evangelicals, subotnick, haunting, computationally, exacerbating, cripps, fadlan,
# Nearest to orthodox: nami, bobble, isabella, vigor, reformation, decoy, attest, cambrensis,
# Nearest to discovered: hitchhiking, corvus, solstice, waddington, view, trammell, furtherance, ingestion,
# Nearest to mathematics: doorways, composition, papias, iota, aswan, ndel, thessalian, unauthorized,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.3472 0.0183 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.3422 0.0172 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.3202 0.0175 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4254 0.0184 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.3740 0.0170 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.3957 0.0170 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.3428 0.0173 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.2843 0.0178 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.3149 0.0174 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3237 0.0173 sec/batch
# Nearest to than: noblesse, lilac, tcm, operated, beauregard, allende, journeyman, forty,
# Nearest to their: deposited, navel, fearless, pasha, option, supplication, casas, sacrifices,
# Nearest to more: needlework, puts, hemophilia, regressive, tefillin, barca, lash, heals,
# Nearest to four: chee, untie, trema, curonian, wadi, tutorials, boulton, dwt,
# Nearest to all: kinsman, term, muds, converts, eurosceptic, samadhi, priestly, intelligences,
# Nearest to nine: unequivocally, singer, estampie, extrinsic, hollies, loya, constitutionally, natalie,
# Nearest to if: theorem, lundy, affix, rarity, irrational, deepen, urbane, impermanence,
# Nearest to where: criticizes, farah, shunning, objection, recurs, neopagans, freyja, europa,
# Nearest to test: cordell, premiers, hyland, culling, haarlem, wagers, macro, increase,
# Nearest to square: bordered, andaman, schiphol, bicycles, hobbled, america, orphaned, serif,
# Nearest to question: xenophon, redress, validity, hebrew, invariants, vapour, chalcedonians, persephone,
# Nearest to versions: yury, scientologists, ekg, headlining, running, contributions, parke, knoppix,
# Nearest to derived: fest, evangelicals, subotnick, expansive, exacerbating, cripps, haunting, fadlan,
# Nearest to orthodox: nami, reformation, bobble, theologians, vigor, isabella, sacrilege, decoy,
# Nearest to discovered: hitchhiking, solstice, corvus, waddington, view, trammell, furtherance, cav,
# Nearest to mathematics: composition, doorways, papias, iota, ndel, masoretic, aswan, unauthorized,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.3331 0.0184 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3000 0.0177 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.3345 0.0172 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.2958 0.0174 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3314 0.0183 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.3626 0.0175 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3029 0.0173 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.2514 0.0176 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3466 0.0177 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.2766 0.0185 sec/batch
# Nearest to than: noblesse, tcm, barcode, lilac, keitai, beauregard, operated, piercer,
# Nearest to their: navel, deposited, fearless, pasha, option, glorified, sacrifices, supplication,
# Nearest to more: needlework, tefillin, hemophilia, puts, regressive, insecticides, heals, lash,
# Nearest to four: chee, trema, untie, dwt, boulton, seven, curonian, tutorials,
# Nearest to all: kinsman, term, samadhi, muds, converts, priestly, letters, intelligences,
# Nearest to nine: singer, unequivocally, estampie, extrinsic, hollies, microchip, loya, natalie,
# Nearest to if: irrational, affix, lundy, rarity, theorem, urbane, endomorphism, commonalities,
# Nearest to where: criticizes, shunning, farah, objection, vestibule, sinh, terrifying, recurs,
# Nearest to test: cordell, premiers, culling, hyland, haarlem, oblivious, wagers, macro,
# Nearest to square: bordered, andaman, serif, schiphol, bicycles, orphaned, downtown, legge,
# Nearest to question: xenophon, invariants, redress, validity, chalcedonians, hebrew, vapour, persephone,
# Nearest to versions: scientologists, yury, ekg, headlining, contributions, running, parke, games,
# Nearest to derived: fest, evangelicals, subotnick, expansive, cripps, influence, fadlan, exacerbating,
# Nearest to orthodox: nami, theologians, reformation, nicene, bobble, ecumenical, lutherans, christians,
# Nearest to discovered: hitchhiking, solstice, corvus, waddington, view, grundlagen, trammell, centaur,
# Nearest to mathematics: papias, doorways, iota, composition, ndel, masoretic, thessalian, reaffirming,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.2821 0.0186 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3100 0.0177 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.2811 0.0183 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.2769 0.0179 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3318 0.0182 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.2645 0.0184 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3018 0.0177 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.2878 0.0177 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.2646 0.0172 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.2509 0.0178 sec/batch
# Nearest to than: noblesse, tcm, operated, beauregard, piercer, forty, keitai, lilac,
# Nearest to their: navel, fearless, deposited, pasha, sacrifices, geode, glorified, option,
# Nearest to more: needlework, truso, hemophilia, puts, tefillin, flattery, heals, insecticides,
# Nearest to four: chee, dwt, seven, trema, curonian, boulton, untie, ghat,
# Nearest to all: kinsman, term, samadhi, letters, muds, generating, eurosceptic, converts,
# Nearest to nine: unequivocally, estampie, extrinsic, constitutionally, loya, singer, gabonese, hollies,
# Nearest to if: irrational, lundy, urbane, endomorphism, affix, rarity, theorem, commonalities,
# Nearest to where: shunning, criticizes, farah, vestibule, sinh, objection, freyja, unmarked,
# Nearest to test: cordell, premiers, culling, oblivious, wagers, hyland, macro, haarlem,
# Nearest to square: bordered, andaman, serif, schiphol, legge, nuisance, schlieffen, hobbled,
# Nearest to question: xenophon, redress, invariants, validity, chalcedonians, persephone, tycho, paradoxes,
# Nearest to versions: scientologists, ekg, yury, running, headlining, contributions, handling, proprietary,
# Nearest to derived: fest, subotnick, evangelicals, expansive, cripps, fadlan, influence, curators,
# Nearest to orthodox: nami, theologians, nicene, bobble, reformation, lutherans, ecumenical, iconography,
# Nearest to discovered: hitchhiking, solstice, corvus, waddington, explanatory, view, centaur, trammell,
# Nearest to mathematics: iota, doorways, papias, ndel, thessalian, composition, masoretic, rudolf,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.2631 0.0186 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.1938 0.0179 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3107 0.0181 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.2963 0.0179 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3307 0.0175 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2113 0.0187 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2212 0.0175 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3028 0.0177 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1570 0.0174 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2058 0.0174 sec/batch
# Nearest to than: noblesse, tcm, forty, operated, psychomotor, allende, renault, piercer,
# Nearest to their: navel, pasha, deposited, fearless, sacrifices, option, glorified, casas,
# Nearest to more: needlework, truso, tefillin, hemophilia, puts, imr, heals, flattery,
# Nearest to four: chee, seven, dwt, trema, boulton, curonian, kirghiz, fiesta,
# Nearest to all: kinsman, term, samadhi, eurosceptic, generating, converts, determinants, luc,
# Nearest to nine: singer, unequivocally, estampie, extrinsic, gabonese, impeding, loya, hollies,
# Nearest to if: irrational, endomorphism, affix, theorem, rarity, urbane, lundy, commonalities,
# Nearest to where: criticizes, shunning, sinh, farah, unmarked, terrifying, vestibule, kyat,
# Nearest to test: cordell, premiers, hyland, culling, oblivious, wagers, univision, macro,
# Nearest to square: bordered, andaman, serif, perturbation, nuisance, schlieffen, legge, chopper,
# Nearest to question: redress, xenophon, invariants, validity, persephone, chalcedonians, vapour, paradoxes,
# Nearest to versions: ekg, scientologists, yury, headlining, turbojet, running, handling, traversal,
# Nearest to derived: fest, subotnick, evangelicals, expansive, fadlan, cripps, influence, curators,
# Nearest to orthodox: nami, theologians, bobble, nicene, lutherans, reformation, iconography, ecumenical,
# Nearest to discovered: solstice, hitchhiking, corvus, waddington, explanatory, centaur, trammell, view,
# Nearest to mathematics: iota, doorways, papias, thessalian, ndel, physics, composition, masoretic,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2419 0.0183 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2495 0.0172 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.2724 0.0085 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.1573 0.0177 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1767 0.0177 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1356 0.0180 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1692 0.0173 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1520 0.0170 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1848 0.0173 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1394 0.0171 sec/batch
# Nearest to than: noblesse, tcm, forty, keitai, operated, edward, allende, sophisticated,
# Nearest to their: navel, deposited, pasha, geode, casas, hopping, glorified, fearless,
# Nearest to more: needlework, truso, hemophilia, tefillin, flattery, imr, influx, puts,
# Nearest to four: chee, seven, dwt, trema, untie, boulton, curonian, idealised,
# Nearest to all: kinsman, term, eurosceptic, generating, footage, intelligences, converts, determinants,
# Nearest to nine: estampie, unequivocally, gabonese, loya, extrinsic, singer, hollies, franciscus,
# Nearest to if: endomorphism, rarity, irrational, lundy, impermanence, affix, urbane, everyday,
# Nearest to where: sinh, criticizes, kyat, shunning, lieutenant, farah, terrifying, freyja,
# Nearest to test: cordell, premiers, hyland, oblivious, culling, univision, malty, extremism,
# Nearest to square: bordered, andaman, serif, downtown, schlieffen, legge, chopper, perturbation,
# Nearest to question: redress, xenophon, validity, persephone, invariants, chalcedonians, vapour, paradoxes,
# Nearest to versions: ekg, scientologists, yury, updates, turbojet, headlining, proprietary, traversal,
# Nearest to derived: fest, subotnick, evangelicals, expansive, fadlan, cripps, influence, curators,
# Nearest to orthodox: nami, theologians, nicene, bobble, lutherans, reformation, iconography, isabella,
# Nearest to discovered: solstice, hitchhiking, corvus, waddington, centaur, sewage, aegon, procuring,
# Nearest to mathematics: iota, papias, composition, ndel, doorways, masoretic, thessalian, hilbert,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2121 0.0184 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2008 0.0172 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1656 0.0172 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.0622 0.0177 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1351 0.0171 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1059 0.0176 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1084 0.0173 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1440 0.0171 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1629 0.0174 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1443 0.0171 sec/batch
# Nearest to than: tcm, noblesse, forty, sophisticated, keitai, piercer, edward, operated,
# Nearest to their: navel, deposited, pasha, geode, casas, preference, fearless, hopping,
# Nearest to more: needlework, truso, tefillin, hemophilia, influx, flattery, benefit, regressive,
# Nearest to four: chee, seven, dwt, trema, idealised, boulton, curonian, untie,
# Nearest to all: kinsman, term, eurosceptic, converts, generating, samadhi, determinants, intelligences,
# Nearest to nine: gabonese, estampie, unequivocally, loya, constitutionally, disassembly, extrinsic, hollies,
# Nearest to if: endomorphism, irrational, lundy, affix, rarity, impermanence, everyday, urbane,
# Nearest to where: sinh, kyat, criticizes, lieutenant, farah, shunning, vestibule, terrifying,
# Nearest to test: cordell, premiers, hyland, oblivious, culling, macro, univision, extremism,
# Nearest to square: bordered, andaman, serif, downtown, chopper, perturbation, legge, schlieffen,
# Nearest to question: redress, invariants, validity, xenophon, vapour, paradoxes, persephone, chalcedonians,
# Nearest to versions: ekg, scientologists, yury, headlining, traversal, updates, turbojet, handling,
# Nearest to derived: fest, subotnick, evangelicals, expansive, fadlan, cripps, saros, influence,
# Nearest to orthodox: theologians, nami, lutherans, nicene, iconography, bobble, reformation, skyview,
# Nearest to discovered: solstice, hitchhiking, corvus, waddington, centaur, procuring, sewage, view,
# Nearest to mathematics: papias, iota, ndel, thessalian, composition, doorways, masoretic, lagrange,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1091 0.0180 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1767 0.0178 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1333 0.0176 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1132 0.0173 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1552 0.0169 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1566 0.0173 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1590 0.0173 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1111 0.0174 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1334 0.0174 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1320 0.0176 sec/batch
# Nearest to than: noblesse, tcm, piercer, sophisticated, forty, edward, abounds, keitai,
# Nearest to their: navel, pasha, deposited, geode, preference, casas, clicking, glorified,
# Nearest to more: needlework, truso, tefillin, flattery, hemophilia, influx, benefit, waqf,
# Nearest to four: seven, chee, dwt, idealised, trema, boulton, untie, sprengel,
# Nearest to all: kinsman, term, generating, eurosceptic, intelligences, samadhi, footage, luc,
# Nearest to nine: gabonese, unequivocally, estampie, loya, hollies, extrinsic, disassembly, constitutionally,
# Nearest to if: endomorphism, irrational, lundy, rarity, affix, impermanence, everyday, urbane,
# Nearest to where: sinh, lieutenant, criticizes, vestibule, kyat, recurs, freyja, multiplicative,
# Nearest to test: cordell, premiers, oblivious, hyland, culling, univision, malty, macro,
# Nearest to square: bordered, andaman, serif, chopper, risch, perturbation, legge, downtown,
# Nearest to question: redress, xenophon, invariants, validity, persephone, chalcedonians, paradoxes, selfishness,
# Nearest to versions: ekg, scientologists, yury, headlining, kabbalist, traversal, updates, turbojet,
# Nearest to derived: fest, subotnick, evangelicals, expansive, cripps, fadlan, saros, curators,
# Nearest to orthodox: nami, theologians, lutherans, bobble, iconography, autocephalous, cambrensis, reformation,
# Nearest to discovered: solstice, hitchhiking, corvus, centaur, procuring, waddington, elliptical, grundlagen,
# Nearest to mathematics: iota, papias, thessalian, ndel, lagrange, doorways, isbns, hilbert,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1716 0.0188 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1715 0.0185 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1467 0.0180 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1510 0.0179 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1257 0.0174 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.0836 0.0184 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1454 0.0188 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0948 0.0181 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1498 0.0182 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1881 0.0181 sec/batch
# Nearest to than: noblesse, edward, sophisticated, tcm, forty, abounds, renault, beauregard,
# Nearest to their: navel, pasha, deposited, casas, geode, preference, glorified, fearless,
# Nearest to more: needlework, truso, influx, benefit, flattery, tefillin, waqf, puts,
# Nearest to four: chee, seven, dwt, trema, idealised, poto, boulton, foiling,
# Nearest to all: kinsman, eurosceptic, term, generating, samadhi, converts, intelligences, kaja,
# Nearest to nine: gabonese, unequivocally, estampie, franciscus, hollies, constitutionally, loya, disassembly,
# Nearest to if: endomorphism, lundy, irrational, rarity, impermanence, urbane, affix, everyday,
# Nearest to where: lieutenant, criticizes, vestibule, freyja, kyat, sinh, farah, abyssinia,
# Nearest to test: cordell, premiers, oblivious, hyland, culling, univision, malty, macro,
# Nearest to square: bordered, andaman, serif, chopper, downtown, legge, perturbation, risch,
# Nearest to question: redress, xenophon, invariants, validity, paradoxes, chalcedonians, persephone, docteur,
# Nearest to versions: ekg, scientologists, yury, updates, kabbalist, headlining, stuffing, loc,
# Nearest to derived: fest, subotnick, evangelicals, fadlan, cripps, expansive, saros, menhir,
# Nearest to orthodox: nami, theologians, bobble, lutherans, iconography, autocephalous, cambrensis, trills,
# Nearest to discovered: solstice, hitchhiking, corvus, centaur, procuring, waddington, brooke, azerbaijanis,
# Nearest to mathematics: iota, thessalian, papias, ndel, professorship, lagrange, rudolf, doorways,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2028 0.0189 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1030 0.0176 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1066 0.0173 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1323 0.0174 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0209 0.0174 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1192 0.0181 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1298 0.0177 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1159 0.0172 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1519 0.0040 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0468 0.0170 sec/batch
# Nearest to than: noblesse, sophisticated, forty, tcm, edward, abounds, renault, keitai,
# Nearest to their: navel, pasha, deposited, casas, preference, geode, hopping, glorified,
# Nearest to more: needlework, truso, influx, benefit, tefillin, lesser, flattery, waqf,
# Nearest to four: seven, chee, dwt, idealised, trema, succubus, untie, poto,
# Nearest to all: kinsman, eurosceptic, term, generating, intelligences, samadhi, converts, footage,
# Nearest to nine: gabonese, unequivocally, estampie, disassembly, americanized, constitutionally, hollies, extrinsic,
# Nearest to if: lundy, endomorphism, rarity, irrational, affix, impermanence, theorem, urbane,
# Nearest to where: sinh, lieutenant, kyat, recurs, criticizes, pant, vestibule, freyja,
# Nearest to test: cordell, premiers, oblivious, univision, hyland, malty, coanda, colleague,
# Nearest to square: bordered, andaman, serif, chopper, symbolizes, perturbation, risch, downtown,
# Nearest to question: redress, xenophon, invariants, validity, paradoxes, persephone, detained, chalcedonians,
# Nearest to versions: ekg, scientologists, knoppix, updates, yury, headlining, workgroup, stuffing,
# Nearest to derived: fest, subotnick, evangelicals, fadlan, cripps, saros, expansive, curators,
# Nearest to orthodox: nami, bobble, theologians, lutherans, iconography, trills, cambrensis, pugwash,
# Nearest to discovered: solstice, hitchhiking, corvus, centaur, procuring, brooke, elliptical, aegon,
# Nearest to mathematics: thessalian, iota, papias, lagrange, physics, ndel, professorship, isbns,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0251 0.0181 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0515 0.0170 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0615 0.0173 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0511 0.0171 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0547 0.0172 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0172 0.0172 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0766 0.0172 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0612 0.0173 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1239 0.0172 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0260 0.0176 sec/batch
# Nearest to than: noblesse, sophisticated, tcm, forty, edward, keitai, renault, operated,
# Nearest to their: navel, pasha, deposited, casas, preference, geode, glorified, fearless,
# Nearest to more: needlework, truso, influx, benefit, tefillin, lesser, hemophilia, puts,
# Nearest to four: seven, chee, dwt, idealised, trema, succubus, boulton, foiling,
# Nearest to all: eurosceptic, kinsman, generating, term, intelligences, samadhi, converts, footage,
# Nearest to nine: gabonese, unequivocally, disassembly, estampie, constitutionally, hollies, loya, americanized,
# Nearest to if: endomorphism, lundy, impermanence, irrational, everyday, affix, rarity, urbane,
# Nearest to where: sinh, lieutenant, recurs, revenues, criticizes, pant, vestibule, riga,
# Nearest to test: cordell, premiers, hyland, malty, univision, colleague, oblivious, coanda,
# Nearest to square: bordered, andaman, serif, symbolizes, chopper, perturbation, legge, risch,
# Nearest to question: redress, xenophon, invariants, paradoxes, validity, persephone, detained, chalcedonians,
# Nearest to versions: ekg, scientologists, knoppix, stuffing, yury, updates, headlining, newt,
# Nearest to derived: fest, subotnick, evangelicals, menhir, fadlan, cripps, saros, expansive,
# Nearest to orthodox: nami, theologians, bobble, lutherans, iconography, cambrensis, trills, pugwash,
# Nearest to discovered: solstice, hitchhiking, corvus, centaur, procuring, brooke, procession, elliptical,
# Nearest to mathematics: iota, thessalian, papias, lagrange, isbns, ndel, composition, professorship,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9993 0.0182 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0356 0.0172 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0211 0.0171 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0534 0.0171 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0643 0.0171 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0471 0.0171 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0385 0.0173 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0776 0.0173 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0279 0.0170 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0425 0.0171 sec/batch
# Nearest to than: sophisticated, noblesse, keitai, forty, tcm, edward, foreshadowed, barcode,
# Nearest to their: navel, pasha, deposited, casas, preference, geode, hopping, highly,
# Nearest to more: needlework, truso, influx, benefit, tefillin, lesser, waqf, hemophilia,
# Nearest to four: seven, chee, dwt, idealised, trema, poto, boulton, succubus,
# Nearest to all: eurosceptic, generating, intelligences, kinsman, exists, term, luc, converts,
# Nearest to nine: gabonese, unequivocally, disassembly, constitutionally, estampie, dimers, hollies, bender,
# Nearest to if: endomorphism, lundy, rarity, affix, everyday, theorem, irrational, empiricists,
# Nearest to where: sinh, pant, recurs, revenues, vestibule, lieutenant, riga, criticizes,
# Nearest to test: cordell, premiers, hyland, oblivious, colleague, univision, malty, coanda,
# Nearest to square: bordered, andaman, serif, symbolizes, risch, chopper, perturbation, eleusis,
# Nearest to question: redress, xenophon, paradoxes, invariants, chalcedonians, vapour, validity, hash,
# Nearest to versions: ekg, scientologists, yury, pebble, stuffing, headlining, knoppix, commissioned,
# Nearest to derived: fest, subotnick, evangelicals, menhir, saros, fadlan, cripps, astm,
# Nearest to orthodox: nami, theologians, lutherans, bobble, iconography, ecumenical, cambrensis, autocephalous,
# Nearest to discovered: solstice, hitchhiking, corvus, centaur, procuring, brooke, elliptical, waddington,
# Nearest to mathematics: iota, thessalian, lagrange, reymond, isbns, papias, numeration, ndel,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0234 0.0180 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0706 0.0172 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0885 0.0171 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0237 0.0171 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0470 0.0170 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0364 0.0169 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0800 0.0172 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0598 0.0175 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0791 0.0173 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0538 0.0171 sec/batch
# Nearest to than: noblesse, sophisticated, edward, keitai, forty, abounds, renault, tcm,
# Nearest to their: pasha, navel, casas, deposited, preference, geode, glorified, highly,
# Nearest to more: truso, needlework, influx, benefit, tefillin, lesser, flattery, puts,
# Nearest to four: seven, idealised, chee, dwt, trema, pnh, boulton, foiling,
# Nearest to all: eurosceptic, generating, kinsman, intelligences, term, samadhi, converts, exists,
# Nearest to nine: gabonese, unequivocally, disassembly, constitutionally, bender, dimers, americanized, loya,
# Nearest to if: endomorphism, lundy, everyday, rarity, affix, urbane, ettinger, mejia,
# Nearest to where: pant, lieutenant, sinh, criticizes, vestibule, recurs, revenues, kyat,
# Nearest to test: cordell, premiers, culling, oblivious, hyland, colleague, malty, coanda,
# Nearest to square: bordered, andaman, serif, symbolizes, chopper, risch, eleusis, downtown,
# Nearest to question: redress, xenophon, invariants, paradoxes, chalcedonians, detained, parchamis, validity,
# Nearest to versions: ekg, scientologists, junkie, stuffing, knoppix, kabbalist, loc, headlining,
# Nearest to derived: fest, subotnick, menhir, evangelicals, saros, cripps, fadlan, catharine,
# Nearest to orthodox: nami, theologians, bobble, lutherans, iconography, trills, cambrensis, congolese,
# Nearest to discovered: solstice, hitchhiking, corvus, centaur, brooke, procuring, conjunctivitis, waddington,
# Nearest to mathematics: thessalian, iota, reymond, professorship, numeration, isbns, papias, henri,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0390 0.0182 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9868 0.0171 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0369 0.0172 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0568 0.0174 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0615 0.0167 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0875 0.0172 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1220 0.0175 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0534 0.0172 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0249 0.0176 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0347 0.0178 sec/batch
# Nearest to than: sophisticated, noblesse, renault, keitai, edward, forty, abounds, beauregard,
# Nearest to their: pasha, navel, casas, deposited, preference, geode, highly, glorified,
# Nearest to more: truso, needlework, influx, benefit, lesser, tefillin, flattery, pirandello,
# Nearest to four: seven, idealised, chee, dwt, trema, pnh, poto, foiling,
# Nearest to all: eurosceptic, kinsman, term, generating, luc, intelligences, converts, samadhi,
# Nearest to nine: gabonese, unequivocally, disassembly, websters, constitutionally, americanized, dimers, estampie,
# Nearest to if: endomorphism, everyday, affix, lundy, rarity, urbane, theorem, empiricists,
# Nearest to where: sinh, lieutenant, criticizes, revenues, pant, recurs, kyat, riga,
# Nearest to test: cordell, premiers, oblivious, colleague, malty, hyland, culling, neisser,
# Nearest to square: bordered, andaman, serif, risch, symbolizes, chopper, perturbation, obstructions,
# Nearest to question: redress, invariants, xenophon, paradoxes, hash, detained, vapour, lha,
# Nearest to versions: ekg, scientologists, knoppix, loc, junkie, stuffing, kabbalist, yury,
# Nearest to derived: fest, subotnick, menhir, evangelicals, cripps, saros, catharine, astm,
# Nearest to orthodox: nami, bobble, theologians, lutherans, iconography, pugwash, trills, cambrensis,
# Nearest to discovered: solstice, corvus, hitchhiking, procuring, brooke, centaur, trammell, conjunctivitis,
# Nearest to mathematics: reymond, iota, thessalian, professorship, numeration, lagrange, henri, papias,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9641 0.0187 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9995 0.0182 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0111 0.0185 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0240 0.0180 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0820 0.0176 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0232 0.0178 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9855 0.0178 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9626 0.0179 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9808 0.0173 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9519 0.0172 sec/batch
# Nearest to than: sophisticated, noblesse, edward, keitai, renault, tcm, forty, foreshadowed,
# Nearest to their: pasha, navel, casas, deposited, geode, preference, glorified, highly,
# Nearest to more: truso, needlework, benefit, influx, lesser, indifferent, tefillin, flattery,
# Nearest to four: seven, chee, idealised, dwt, alexandrovich, poto, trema, boulton,
# Nearest to all: eurosceptic, kinsman, converts, intelligences, generating, luc, exists, determinants,
# Nearest to nine: gabonese, unequivocally, virologist, disassembly, millington, singer, sargent, basten,
# Nearest to if: lundy, affix, everyday, endomorphism, rarity, urbane, impermanence, empiricists,
# Nearest to where: lieutenant, pant, sinh, criticizes, recurs, vestibule, kyat, riga,
# Nearest to test: cordell, premiers, malty, oblivious, coanda, hyland, sioux, neisser,
# Nearest to square: bordered, andaman, serif, risch, symbolizes, obstructions, eleusis, chopper,
# Nearest to question: redress, xenophon, invariants, chalcedonians, paradoxes, parchamis, detained, vapour,
# Nearest to versions: ekg, knoppix, scientologists, stuffing, loc, junkie, kickstart, headlining,
# Nearest to derived: fest, subotnick, menhir, evangelicals, saros, cripps, fadlan, catharine,
# Nearest to orthodox: nami, bobble, theologians, lutherans, iconography, cambrensis, congolese, pugwash,
# Nearest to discovered: solstice, hitchhiking, corvus, procuring, centaur, brooke, aegon, bantu,
# Nearest to mathematics: iota, professorship, reymond, thessalian, numeration, lagrange, papias, isbns,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0078 0.0178 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9492 0.0171 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0164 0.0174 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0126 0.0172 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0505 0.0172 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9924 0.0172 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9155 0.0175 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9603 0.0182 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9343 0.0176 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0156 0.0178 sec/batch
# Nearest to than: keitai, noblesse, sophisticated, edward, forty, foreshadowed, abounds, piercer,
# Nearest to their: pasha, navel, deposited, casas, preference, geode, highly, hopping,
# Nearest to more: truso, needlework, influx, benefit, lesser, tefillin, regressive, flattery,
# Nearest to four: seven, idealised, chee, dwt, pnh, trema, ghat, boulton,
# Nearest to all: eurosceptic, generating, considering, converts, helices, benthic, intelligences, exists,
# Nearest to nine: gabonese, disassembly, dimers, unequivocally, constitutionally, loya, ghanaian, bender,
# Nearest to if: endomorphism, lundy, affix, everyday, rarity, urbane, betting, theorem,
# Nearest to where: pant, revenues, sinh, lieutenant, vestibule, kyat, recurs, criticizes,
# Nearest to test: cordell, premiers, malty, neisser, cricket, oblivious, coanda, hyland,
# Nearest to square: bordered, andaman, risch, symbolizes, serif, obstructions, eleusis, orphaned,
# Nearest to question: redress, invariants, xenophon, paradoxes, chalcedonians, parchamis, vapour, hash,
# Nearest to versions: ekg, scientologists, knoppix, stuffing, newt, yury, kabbalist, headlining,
# Nearest to derived: fest, menhir, subotnick, evangelicals, saros, astm, catharine, switzerland,
# Nearest to orthodox: nami, theologians, lutherans, bobble, congolese, cambrensis, iconography, trills,
# Nearest to discovered: solstice, procuring, corvus, hitchhiking, brooke, bantu, centaur, aegon,
# Nearest to mathematics: iota, professorship, reymond, numeration, thessalian, physics, lagrange, papias,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0057 0.0185 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0043 0.0177 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9980 0.0173 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9864 0.0172 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0516 0.0173 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9599 0.0182 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0161 0.0171 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0144 0.0176 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0202 0.0177 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0028 0.0179 sec/batch
# Nearest to than: keitai, noblesse, sophisticated, foreshadowed, edward, abounds, forty, piercer,
# Nearest to their: pasha, preference, navel, casas, geode, deposited, highly, myron,
# Nearest to more: truso, needlework, benefit, influx, tefillin, lesser, flattery, indifferent,
# Nearest to four: seven, idealised, chee, trema, dwt, poto, pnh, alexandrovich,
# Nearest to all: eurosceptic, generating, converts, considering, samadhi, chairperson, kinsman, prelate,
# Nearest to nine: gabonese, unequivocally, disassembly, singer, virologist, millington, dimers, bender,
# Nearest to if: lundy, endomorphism, affix, rarity, everyday, urbane, empiricists, impermanence,
# Nearest to where: pant, sinh, recurs, revenues, vestibule, lieutenant, kyat, criticizes,
# Nearest to test: cordell, premiers, cricket, malty, oblivious, coanda, culling, neisser,
# Nearest to square: bordered, risch, andaman, serif, symbolizes, eleusis, orphaned, obstructions,
# Nearest to question: redress, invariants, xenophon, paradoxes, chalcedonians, lha, hash, parchamis,
# Nearest to versions: ekg, knoppix, scientologists, junkie, loc, newt, richland, yury,
# Nearest to derived: fest, menhir, subotnick, saros, astm, catharine, evangelicals, switzerland,
# Nearest to orthodox: nami, theologians, cambrensis, bobble, trills, lutherans, congolese, iconography,
# Nearest to discovered: corvus, procuring, hitchhiking, solstice, brooke, centaur, elliptical, bantu,
# Nearest to mathematics: professorship, iota, reymond, numeration, thessalian, isbns, henri, papias,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0228 0.0182 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9818 0.0178 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0079 0.0178 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9932 0.0173 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0038 0.0173 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9986 0.0172 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9898 0.0171 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9673 0.0169 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9562 0.0171 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0105 0.0172 sec/batch
# Nearest to than: noblesse, sophisticated, keitai, edward, abounds, foreshadowed, forty, piercer,
# Nearest to their: pasha, casas, preference, navel, geode, deposited, highly, obliged,
# ...
# Nearest to mathematics: reymond, professorship, numeration, thessalian, iota, crandall, efforts, pirenne,
# Epoch 9/10 Iteration: 37100 Avg. Training loss: 3.8784 0.0165 sec/batch
# Epoch 9/10 Iteration: 37200 Avg. Training loss: 3.8702 0.0175 sec/batch
# Epoch 9/10 Iteration: 37300 Avg. Training loss: 3.8702 0.0170 sec/batch
# Epoch 9/10 Iteration: 37400 Avg. Training loss: 3.8965 0.0172 sec/batch
# Epoch 9/10 Iteration: 37500 Avg. Training loss: 3.8650 0.0173 sec/batch
# Epoch 9/10 Iteration: 37600 Avg. Training loss: 3.8451 0.0174 sec/batch
# Epoch 9/10 Iteration: 37700 Avg. Training loss: 3.8138 0.0173 sec/batch
# Epoch 9/10 Iteration: 37800 Avg. Training loss: 3.8846 0.0174 sec/batch
# Epoch 9/10 Iteration: 37900 Avg. Training loss: 3.8557 0.0172 sec/batch
# Epoch 9/10 Iteration: 38000 Avg. Training loss: 3.8990 0.0178 sec/batch
# Nearest to than: foreshadowed, keitai, forty, sophisticated, devote, noblesse, most, according,
# Nearest to their: to, obliged, amoeboid, highly, casas, they, preference, aggressors,
# Nearest to more: benefit, truso, eaux, secularization, flattery, programmability, compensating, apologists,
# Nearest to four: seven, one, six, five, three, nine, eight, two,
# Nearest to all: converts, intelligences, dentition, time, denote, considering, silverstone, pmod,
# Nearest to nine: zero, gabonese, six, seven, one, eight, four, websters,
# Nearest to if: lundy, you, coco, affix, endomorphism, urbane, everyday, centimetres,
# Nearest to where: revenues, projectile, pant, recurs, infimum, vestibule, softworks, gynecology,
# Nearest to test: cricket, tests, cordell, premiers, mmc, coanda, manifest, non,
# Nearest to square: bordered, obstructions, risch, memorials, eleusis, metres, andaman, fences,
# Nearest to question: lha, redress, western, invariants, boo, harwood, hamilton, nkjv,
# Nearest to versions: noting, ekg, us, amraam, parke, junkie, machinegun, headlining,
# Nearest to derived: catharine, fest, menhir, astm, prostitutes, thant, switzerland, connotations,
# Nearest to orthodox: nami, lexicographic, theologians, iconography, conscripts, lutherans, calligraphers, pugwash,
# Nearest to discovered: bantu, procuring, manmade, brooke, conjunctivitis, procession, cuvier, bacilli,
# Nearest to mathematics: professorship, reymond, numeration, iota, efforts, thessalian, fermat, pirenne,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8730 0.0191 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7689 0.0182 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8391 0.0178 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.8267 0.0172 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8529 0.0173 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8755 0.0174 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8793 0.0179 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8530 0.0175 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8651 0.0171 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9314 0.0172 sec/batch
# Nearest to than: foreshadowed, forty, sophisticated, devote, keitai, most, according, noblesse,
# Nearest to their: to, obliged, amoeboid, they, highly, underpants, preference, wilf,
# Nearest to more: benefit, truso, eaux, programmability, apologists, indifferent, secularization, compensating,
# Nearest to four: seven, one, six, five, three, nine, eight, two,
# Nearest to all: converts, intelligences, pmod, denote, time, silverstone, dentition, exists,
# Nearest to nine: zero, gabonese, six, one, seven, eight, four, three,
# Nearest to if: lundy, you, coco, endomorphism, affix, empiricists, urbane, wff,
# Nearest to where: revenues, projectile, pant, infimum, vestibule, recurs, softworks, sinh,
# Nearest to test: tests, cricket, cordell, mmc, premiers, coanda, manifest, non,
# Nearest to square: bordered, obstructions, risch, memorials, metres, eleusis, andaman, couched,
# Nearest to question: redress, lha, western, invariants, harwood, paradoxes, chemokine, nkjv,
# Nearest to versions: noting, ekg, parke, amraam, junkie, us, machinegun, headlining,
# Nearest to derived: catharine, astm, fest, menhir, prostitutes, connotations, statehood, switzerland,
# Nearest to orthodox: lexicographic, nami, theologians, lutherans, pugwash, conscripts, calligraphers, iconography,
# Nearest to discovered: bantu, procuring, manmade, conjunctivitis, brooke, procession, bacilli, cuvier,
# Nearest to mathematics: professorship, reymond, numeration, efforts, iota, fermat, math, thessalian,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8466 0.0185 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8561 0.0172 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8719 0.0169 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8746 0.0170 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.9013 0.0171 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8834 0.0176 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8722 0.0174 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8480 0.0173 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8802 0.0172 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.9086 0.0174 sec/batch
# Nearest to than: foreshadowed, forty, keitai, devote, sophisticated, noblesse, intermediate, according,
# Nearest to their: to, they, obliged, highly, raiders, amoeboid, casas, wilf,
# Nearest to more: benefit, truso, apologists, secularization, indifferent, eaux, most, programmability,
# Nearest to four: seven, one, six, five, three, nine, eight, zero,
# Nearest to all: converts, denote, pmod, time, intelligences, christina, exists, shizuka,
# Nearest to nine: zero, gabonese, one, six, seven, four, three, eight,
# Nearest to if: lundy, you, endomorphism, coco, urbane, affix, wff, convenes,
# Nearest to where: revenues, projectile, pant, infimum, vestibule, softworks, gynecology, recurs,
# Nearest to test: cordell, tests, cricket, mmc, premiers, coanda, non, manifest,
# Nearest to square: bordered, obstructions, risch, memorials, eleusis, metres, fences, couched,
# Nearest to question: lha, redress, invariants, western, harwood, answered, hamilton, nkjv,
# Nearest to versions: noting, ekg, amraam, junkie, parke, us, kabbalist, machinegun,
# Nearest to derived: catharine, astm, menhir, fest, thant, prostitutes, switzerland, jud,
# Nearest to orthodox: nami, lexicographic, pugwash, lutherans, conscripts, theologians, autocephalous, iconography,
# Nearest to discovered: bantu, procuring, manmade, conjunctivitis, brooke, horoscopes, elliptical, cuvier,
# Nearest to mathematics: professorship, reymond, numeration, fermat, efforts, thessalian, iota, pirenne,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8785 0.0183 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8560 0.0173 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8416 0.0174 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8547 0.0170 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9267 0.0171 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8553 0.0173 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9797 0.0173 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9124 0.0172 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9414 0.0176 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8383 0.0171 sec/batch
# Nearest to than: forty, foreshadowed, keitai, devote, sophisticated, noblesse, according, most,
# Nearest to their: to, they, amoeboid, raiders, obliged, highly, preference, wilf,
# Nearest to more: benefit, truso, indifferent, eaux, apologists, various, secularization, most,
# Nearest to four: seven, one, six, five, three, nine, eight, zero,
# Nearest to all: converts, eurosceptic, denote, christina, time, shizuka, considering, silverstone,
# Nearest to nine: zero, one, gabonese, six, seven, four, eight, three,
# Nearest to if: you, lundy, coco, urbane, endomorphism, wff, affix, convenes,
# Nearest to where: revenues, projectile, pant, vestibule, infimum, columbo, softworks, recurs,
# Nearest to test: cordell, tests, cricket, mmc, premiers, coanda, manifest, non,
# Nearest to square: bordered, risch, obstructions, memorials, metres, eleusis, couched, andaman,
# Nearest to question: lha, harwood, redress, answered, invariants, western, fddi, hamilton,
# Nearest to versions: noting, amraam, junkie, ekg, parke, us, kabbalist, machinegun,
# Nearest to derived: catharine, menhir, fest, astm, thant, prostitutes, jud, remey,
# Nearest to orthodox: lexicographic, nami, pugwash, conscripts, calligraphers, salus, lutherans, ecumenism,
# Nearest to discovered: bantu, procuring, manmade, conjunctivitis, brooke, cuvier, procession, horoscopes,
# Nearest to mathematics: numeration, professorship, reymond, thessalian, efforts, iota, fermat, pirenne,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8085 0.0178 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8613 0.0171 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8108 0.0172 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8695 0.0171 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8678 0.0172 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8739 0.0173 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8815 0.0115 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8460 0.0174 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8589 0.0180 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8957 0.0179 sec/batch
# Nearest to than: forty, keitai, foreshadowed, devote, sophisticated, according, most, intermediate,
# Nearest to their: to, they, obliged, raiders, amoeboid, highly, casas, preference,
# Nearest to more: benefit, truso, apologists, indifferent, eaux, mestizos, secularization, various,
# Nearest to four: seven, one, five, six, three, nine, eight, zero,
# Nearest to all: denote, christina, converts, dentition, time, eurosceptic, exists, lemmas,
# Nearest to nine: zero, one, six, gabonese, seven, four, eight, three,
# Nearest to if: lundy, you, coco, urbane, affix, convenes, fries, quaternion,
# Nearest to where: revenues, projectile, pant, gynecology, vestibule, infimum, recurs, basayev,
# Nearest to test: tests, cordell, cricket, mmc, coanda, premiers, manifest, non,
# Nearest to square: bordered, risch, metres, obstructions, memorials, eleusis, fences, andaman,
# Nearest to question: lha, western, redress, harwood, answered, hamilton, paradoxes, boo,
# Nearest to versions: noting, amraam, junkie, ekg, version, machinegun, us, parke,
# Nearest to derived: catharine, menhir, astm, fest, incorrect, thant, jud, prostitutes,
# Nearest to orthodox: nami, lexicographic, pugwash, conscripts, lutherans, calligraphers, salus, dualist,
# Nearest to discovered: bantu, procuring, manmade, conjunctivitis, procession, brooke, cuvier, horoscopes,
# Nearest to mathematics: professorship, numeration, efforts, reymond, thessalian, iota, pirenne, henri,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8394 0.0184 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8688 0.0174 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8291 0.0174 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8383 0.0175 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8931 0.0171 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8509 0.0174 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8818 0.0176 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7014 0.0179 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8271 0.0179 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7945 0.0176 sec/batch
# Nearest to than: forty, keitai, foreshadowed, according, devote, sophisticated, intermediate, most,
# Nearest to their: to, they, obliged, amoeboid, raiders, highly, casas, own,
# Nearest to more: benefit, truso, apologists, various, secularization, eaux, most, indifferent,
# Nearest to four: seven, one, five, six, three, nine, eight, zero,
# Nearest to all: considering, converts, denote, dentition, pmod, time, eurosceptic, christina,
# Nearest to nine: zero, one, six, gabonese, seven, four, eight, three,
# Nearest to if: you, lundy, coco, affix, endomorphism, wff, equilateral, quaternion,
# Nearest to where: revenues, projectile, pant, vestibule, infimum, gynecology, basayev, recurs,
# Nearest to test: tests, cricket, cordell, mmc, coanda, premiers, non, manifest,
# Nearest to square: obstructions, bordered, metres, risch, memorials, eleusis, fences, couched,
# Nearest to question: lha, western, answered, harwood, chemokine, redress, fddi, sluggish,
# Nearest to versions: noting, ekg, amraam, junkie, version, parke, machinegun, dared,
# Nearest to derived: catharine, astm, fest, menhir, incorrect, prostitutes, connotations, switzerland,
# Nearest to orthodox: lexicographic, pugwash, nami, conscripts, lutherans, dualist, ecumenism, salus,
# Nearest to discovered: bantu, procuring, manmade, conjunctivitis, brooke, cuvier, procession, isolated,
# Nearest to mathematics: professorship, numeration, efforts, reymond, iota, thessalian, henri, aswan,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.8031 0.0183 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8625 0.0172 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8783 0.0178 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8304 0.0173 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8577 0.0177 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9091 0.0172 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8423 0.0170 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8332 0.0175 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8786 0.0173 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8663 0.0175 sec/batch
# Nearest to than: foreshadowed, forty, keitai, devote, intermediate, most, according, biggest,
# Nearest to their: to, they, obliged, preference, highly, raiders, wilf, casas,
# Nearest to more: benefit, truso, most, apologists, indifferent, compensating, various, secularization,
# Nearest to four: seven, one, five, six, three, nine, eight, zero,
# Nearest to all: denote, pmod, considering, christina, for, exists, converts, topologically,
# Nearest to nine: one, zero, six, gabonese, seven, four, three, eight,
# Nearest to if: lundy, you, coco, affix, fries, centimetres, urbane, pages,
# Nearest to where: projectile, infimum, revenues, pant, gynecology, vestibule, recurs, softworks,
# Nearest to test: tests, cordell, cricket, mmc, coanda, premiers, non, manifest,
# Nearest to square: obstructions, bordered, metres, risch, memorials, fences, eleusis, narmer,
# Nearest to question: western, lha, answered, fddi, harwood, redress, hamilton, chemokine,
# Nearest to versions: junkie, noting, amraam, version, machinegun, kabbalist, scientologists, dared,
# Nearest to derived: astm, catharine, incorrect, fest, menhir, prostitutes, switzerland, verdicts,
# Nearest to orthodox: lexicographic, pugwash, conscripts, nami, theologians, dualist, lutherans, autocephalous,
# Nearest to discovered: bantu, procuring, conjunctivitis, manmade, brooke, cuvier, isolated, specimen,
# Nearest to mathematics: professorship, reymond, efforts, numeration, thessalian, iota, henri, physics,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8686 0.0185 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8734 0.0174 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8598 0.0169 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8494 0.0173 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8728 0.0170 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8591 0.0173 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8525 0.0174 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8895 0.0173 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8235 0.0172 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
